# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %% [markdown]
# # Barclays Mortgages

# %% [markdown]
# See: https://www.barclays.co.uk/mortgages/mortgage-calculator/cost-calculator/#/cost

# %%
url = 'https://www.barclays.co.uk/dss/service/co.uk/mortgages/costcalculator/productservice'

# %%
estimatedPropertyValue, repaymentAmount, months, wantTo = 200000, 150000, 240, 'FTBP'

# %%
data = {"header": {"flowId":"0"},
            "body":
            {"wantTo": wantTo,
             "estimatedPropertyValue": estimatedPropertyValue,
             "borrowAmount": repaymentAmount,
             "interestOnlyAmount": 0,
             "repaymentAmount": repaymentAmount,
             "ltv": round(repaymentAmount/estimatedPropertyValue*100),
             "totalTerm": months,
             "purchaseType": "Repayment"}}

# %%
r = requests.post(url, json=data)
results = r.json()

# %%
print(results)
# Out:
# {'header': {'result': 'error', 'systemError': {'errorCode': 'DSS_SEF001', 'type': 'E', 'severity': 'FRAMEWORK', 'errorMessage': 'State details not found in database', 'validationErrors': [], 'contentType': 'application/json', 'channel': '6'}}}

# %%
headers = {
    # These are non-typical headers, let's include them
    'currentState': 'default_current_state',
    'action': 'default',
    'Origin': 'https://www.barclays.co.uk',
    # Spoof referer, user agent, and X-Requested-With
    'Referer': 'https://www.barclays.co.uk/mortgages/mortgage-calculator/',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.62 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
}

# %%
r = requests.post(url, json=data, headers=headers)
results = r.json()    

print(results)
# Out:
# {'header': {'result': 'success', 'errorState': {'name': ['default_error_state'], 'page': 'default_error_page'}, 'successState': {'name': ['default_success_state'], 'page': 'default_success_page'}, 'flowId': '0'}, 'body': {'success': True, 'timeStamp': '2019-03-20T09:55+0000', 'errorMessage': None, 'mortgages': [{'mortgageName': '5 Year Fixed with ��1000 cashback (Purchase Only)', 'mortgageId': '1321127853346', 'ctaType': None, 'uniqueId': '5bd9ae4c68d62b6d6c75096a', 'mortgageType': 'FIXED', 'howMuchCanBeBorrowedNote': '95% (max) of the value of your home', 'initialRate': 3.63, 'initialRateTitle': '3.63%', 'initialRateNote': 'until 30th April 2024', 'followOnRate': 4.24, 'followOnRateTitle': '4.24% (BEBR + 3.49%)', 'followOnRateNote': 'variable for the remaining term *', 'overallCost': 4.1, 'overallCostTitle': '4.1% APRC', 'overallCostNote': 'APRC', 'minLtv': 0.0, 'maxLtv': 95.0, 'applicationFee': '0', 'earlyRepaymentCharges': '3 % of the balance repaid until 30 April 2024', 'minLoanAmount': 50000.0, 'maxLoanAmount': 375000.0, 'eligibility': {'firstTimeBuyer': True, 'secondHome': True, 'remortgage': False, 'movingHome': True}, 'loyalty': False, 'restType': 'Daily', 'freeLegal': 'false', 'overridingInfo': '', 'findOutMoreText': 'Apply', 'initialRateHasBbbr': False, 'initialRateValidUntil': '2024-04-30T22:59:59.999Z', 'initialRateTitleTables': '3.63%', 'repaymentsForFixedPeriod': None, 'totalPayment': 217779.43, 'interestPayment': None, 'aprValue': 4.0, 'monthlyRepaymentHolder': {'monthlyRepaymentForFixedTerm': 879.99, 'interestOnlyPaymentForFixed': 0.0, 'fixedTermPeriod': 61, 'monthlyRepaymentForRemainingTerm': 916.76, 'interestOnlyPaymentForRemainingTerm': 0.0, 'remainingTermPeriod': 179}, 'annualSummaryForFixed': [{'capitalRepayment': 5234.97, 'interestRepayment': 5324.91, 'remainingAmount': 144765.03}, {'capitalRepayment': 5404.17, 'interestRepayment': 5155.71, 'remainingAmount': 139360.86}, {'capitalRepayment': 5592.55, 'interestRepayment': 4967.33, 'remainingAmount': 133768.31}, {'capitalRepayment': 5799.08, 'interestRepayment': 4760.8, 'remainingAmount': 127969.23}, {'capitalRepayment': 6003.64, 'interestRepayment': 4556.24, 'remainingAmount': 121965.59}, {'capitalRepayment': 504.89, 'interestRepayment': 375.1, 'remainingAmount': 121460.7}], 'annualSummaryForVariable': [{'capitalRepayment': 5480.38, 'interestRepayment': 4603.98, 'remainingAmount': 115980.32}, {'capitalRepayment': 6201.23, 'interestRepayment': 4799.89, 'remainingAmount': 109779.09}, {'capitalRepayment': 6470.09, 'interestRepayment': 4531.03, 'remainingAmount': 103309.0}, {'capitalRepayment': 6741.24, 'interestRepayment': 4259.88, 'remainingAmount': 96567.76}, {'capitalRepayment': 7049.57, 'interestRepayment': 3951.55, 'remainingAmount': 89518.19}, {'capitalRepayment': 7345.67, 'interestRepayment': 3655.45, 'remainingAmount': 82172.52}, {'capitalRepayment': 7663.48, 'interestRepayment': 3337.64, 'remainingAmount': 74509.04}, {'capitalRepayment': 7988.95, 'interestRepayment': 3012.17, 'remainingAmount': 66520.09}, {'capitalRepayment': 8345.7, 'interestRepayment': 2655.42, 'remainingAmount': 58174.39}, {'capitalRepayment': 8701.17, 'interestRepayment': 2299.95, 'remainingAmount': 49473.22}, {'capitalRepayment': 9077.38, 'interestRepayment': 1923.74, 'remainingAmount': 40395.84}, {'capitalRepayment': 9466.91, 'interestRepayment': 1534.21, 'remainingAmount': 30928.93}, {'capitalRepayment': 9881.23, 'interestRepayment': 1119.89, 'remainingAmount': 21047.7}, {'capitalRepayment': 10306.68, 'interestRepayment': 694.44, 'remainingAmount': 10741.02}, {'capitalRepayment': 10751.6, 'interestRepayment': 249.52, 'remainingAmount': -10.58}], 'upfrontFee': 35.0, 'backEndFee': 80.0, 'trackerInitialTerm': -1}, {'mortgageName': '2 Year Fixed with ��1000 Cashback (Purchase Only)', 'mortgageId': '1321127853346', 'ctaType': None, 'uniqueId': '5b71497fabab28b8d004edf6', 'mortgageType': 'FIXED', 'howMuchCanBeBorrowedNote': '95% (max) of the value of your home', 'initialRate': 3.47, ...

# %% [markdown]
# # Reuters Board Members

# %%
session = requests.Session()

# %%
sp500 = 'https://www.reuters.com/finance/markets/index/.SPX'

# %%
page = 1
regex = re.compile(r'\/finance\/stocks\/overview\/.*')
symbols = []

# %%
while True:
    print('Scraping page:', page)
    params = {'sortBy': '', 'sortDir' : '', 'pn': page}
    html = session.get(sp500, params=params).text
    soup = BeautifulSoup(html, "html.parser")
    pagenav = soup.find(class_='pageNavigation')
    if not pagenav:
        break
    companies = pagenav.find_next('table', class_='dataTable')
    for link in companies.find_all('a', href=regex):
        symbols.append(link.get('href').split('/')[-1])
    page += 1
# Out:
# Scraping page: 1
# Scraping page: 2
# Scraping page: 3
# Scraping page: 4
# Scraping page: 5
# Scraping page: 6
# Scraping page: 7
# Scraping page: 8
# Scraping page: 9
# Scraping page: 10
# Scraping page: 11
# Scraping page: 12
# Scraping page: 13
# Scraping page: 14
# Scraping page: 15
# Scraping page: 16
# Scraping page: 17
# Scraping page: 18

# %%
symbols[:3]
# Out:
# ['MMM.N', 'AOS.N', 'ABT.N']

# %%
officers = 'https://www.reuters.com/finance/stocks/company-officers/{symbol}'

# %%
dfs = []

# %%
for symbol in symbols[:10]:
    print('Scraping symbol:', symbol)
    html = session.get(officers.format(symbol=symbol)).text
    soup = BeautifulSoup(html, "html.parser")
    officer_table = soup.find('table', {"class" : "dataTable"})
    df = pd.read_html(str(officer_table), header=0)[0]
    df.insert(0, 'symbol', symbol)
    dfs.append(df)

df = pd.concat(dfs)
# Out:
# Scraping symbol: MMM.N
# Scraping symbol: AOS.N
# Scraping symbol: ABT.N
# Scraping symbol: ABBV.N
# Scraping symbol: ABMD.OQ
# Scraping symbol: ACN.N
# Scraping symbol: ATVI.OQ
# Scraping symbol: ADNT.N
# Scraping symbol: ADBE.OQ
# Scraping symbol: AMD.OQ

# %%
df.head()
# Out:
#   symbol                Name   Age   Since  \
# 0  MMM.N         Inge Thulin  65.0  2018.0
# 1  MMM.N       Michael Roman  59.0  2018.0
# 2  MMM.N            Hak Shin  61.0  2017.0
# 3  MMM.N  Nicholas Gangestad  53.0  2014.0
# 4  MMM.N        James Bauman  58.0  2017.0
#
#                                     Current Position
# 0         Executive Chairman of the Board, President
# 1                  Chief Executive Officer, Director
# 2         Vice Chairman and Executive Vice President
# 3     Chief Financial Officer, Senior Vice President
# 4  Executive Vice President, Industrial Business ...
