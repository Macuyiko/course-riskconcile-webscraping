# %% [markdown]
# # Preamble

# %%
import requests
from bs4 import BeautifulSoup
from bs4 import NavigableString
from htmllaundry import sanitize
from htmllaundry.cleaners import LaundryCleaner
import htmllaundry.utils

import xmltodict

import re
import json

from pprint import pprint

import pandas as pd

from glob import glob

# %%
# Cached requests session to ease load on the server

from cachecontrol import CacheControl

sess = requests.session()
cach = CacheControl(sess)

# %%
# Helper for HTML popups

from IPython.display import HTML

def window(html):
    s = '<script type="text/javascript">'
    s += 'var win = window.open("", "", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
    s += 'win.document.body.innerHTML = \'' + html.replace("\n",'\\n').replace("'", "\\'") + '\';'
    s += '</script>'
    return HTML(s)

# %%
# Override default empty tag behavior of htmllaundry, we want to retain some empty tags

if not 'old_remove_empty_tags' in locals(): old_remove_empty_tags = htmllaundry.utils.remove_empty_tags
htmllaundry.utils.remove_empty_tags = lambda doc : old_remove_empty_tags(doc, ['td', 'th'])

# %%
# Custom cleaner class

CustomCleaner = LaundryCleaner(
            page_structure=False,
            remove_unknown_tags=False,
            allow_tags=['blockquote', 'a', 'i', 'em', 'p', 'b', 'strong',
                        'h1', 'h2', 'h3', 'h4', 'h5', 
                        'ul', 'ol', 'li', 
                        'sub', 'sup',
                        'abbr', 'acronym', 'dl', 'dt', 'dd', 'cite',
                        'dft', 'br', 
                        'table', 'tr', 'td', 'th', 'thead', 'tbody', 'tfoot'],
            safe_attrs_only=True,
            add_nofollow=True,
            scripts=True,
            javascript=True,
            comments=True,
            style=True,
            links=False,
            meta=True,
            processing_instructions=False,
            frames=True,
            annoying_tags=False)

# %%
# Fix SEC encoding issues
# See: https://stackoverflow.com/questions/17392422/how-to-decode-cp1252-which-is-in-decimal-147-instead-of-x93

def reformat_cp1252(match):
    codePoint = int(match.group(1))
    if 128 <= codePoint <= 159:
        return bytes([codePoint])
    else:
        return match.group()

def clean_sec_content(binary):
    return re.sub(b'&#(\d+);', reformat_cp1252, binary, flags=re.I).decode("windows-1252").encode('utf-8').decode('utf-8')

# %%
# Normalize strings

def slugify(value):
    import unicodedata
    value = unicodedata.normalize('NFKD', value).encode('ascii', 'ignore').decode('ascii')
    value = re.sub('[^\w\s\.\-]', '-', value).strip().lower()
    value = re.sub('[-\s]+', '-', value)
    return value
    
slugify('test/string.html')
# Out:
# 'test-string.html'

# %% [markdown]
# # Basic SEC scraping

# %%
base_url = 'https://www.sec.gov{}'

# %% [markdown]
# ## Get ticker list

# %%
# Used by the main search field at https://www.sec.gov/

tickers = cach.get(base_url.format('/files/company_tickers.json')).json()

# %%
list(tickers.values())[:3]
# Out:
# [{'cik_str': 320193,
#   'title': 'Apple Inc.',
#   'ticker': 'AAPL',
#   'type': 'company',
#   'total': 1493092},
#  {'cik_str': 19617,
#   'title': 'JPMorgan Chase & Co.',
#   'ticker': 'JPM',
#   'type': 'company',
#   'total': 1462835},
#  {'cik_str': 1534504,
#   'title': 'PBF Energy Inc.',
#   'ticker': 'PBF',
#   'type': 'company',
#   'total': 1449404}]

# %% [markdown]
# ## Helper functions

# %% [markdown]
# We define a general `get_sec_table` method to fetch out tables from SEC pages, with support for pagination and custom URL parameters.

# %%
def pagination_provider_by_element_start_count(find_args, find_kwargs):
    def pagination_provider_by_element_start_count_wrapped(soup, params):
        if soup.find(*find_args, **find_kwargs) is None:
            return None
        params['start'] += params['count']
        return params
    return pagination_provider_by_element_start_count_wrapped

# %%
def params_provider_by_dict(params):
    return lambda : params

# %%
def table_provider_by_summary(summary, header=0, index_col=0):
    return lambda soup: pd.read_html(
        str(soup.find('table', summary=summary)).replace('<br>', '<br>\n'), header=header, index_col=index_col)[0]

# %%
def get_sec_table(url,
                  table_provider=None,
                  base_params={}, 
                  params_provider=None,
                  pagination_provider=None,
                  replace_links=True,
                  session=None):
    def return_data_frame(session, url, params, provider):
        request = session.get(url, params=params)
        soup = BeautifulSoup(request.text)
        if replace_links:
            for a in soup.find_all('a'):
                parent = a.find_parent('td')
                if parent: parent.string = a['href']
        df = provider(soup)
        return df, soup
    if session is None:
        session = cach
    if not url.startswith('http://') and not url.startswith('https://'):
        url = base_url.format(url)
    params = dict(base_params)
    if params_provider:
        if isinstance(params_provider, dict):
            params.update(params_provider)
        else:
            params.update(params_provider())
    if not pagination_provider:
        df, soup = return_data_frame(session, url, params, table_provider)
        return df
    else:
        data_frames = []
        page_params = dict(params)
        while True:
            df, soup = return_data_frame(session, url, page_params, table_provider)
            data_frames.append(df)
            # Make sure columns retain their names
            data_frames[-1].columns = data_frames[0].columns
            new_params = pagination_provider(soup, page_params)
            if not new_params:
                break
            else:
                page_params.update(new_params)
        return pd.concat(data_frames, sort=False, ignore_index=True)

# %% [markdown]
# ## Search by name

# %% [markdown]
# Retrieve CIK numbers based on name search, as featured on the main page.

# %%
# We could do it this way:

def get_companies_by_name(name):
    soup = BeautifulSoup(sess.get(base_url.format('/cgi-bin/browse-edgar'),
             params={'company': name, 'owner': 'exclude', 'action': 'getcompany'}).text)
    return pd.read_html(str(soup.find('table', summary='Results')), header=0, index_col=0)[0]

get_companies_by_name('tesla').head(2)
# Out:
#                                Company State/Country
# CIK
# 1728203  Tesla Auto Lease Trust 2018-A            CA
# 1345028   TESLA GROUP HOLDINGS PTY LTD            C3

# %%
# This is more generic, using our helper:

get_companies_by_name = lambda name : get_sec_table('/cgi-bin/browse-edgar', 
              params_provider={'company': name, 'owner': 'exclude', 'action': 'getcompany'},
              table_provider=table_provider_by_summary('Results'),
              replace_links=False)

get_companies_by_name('tesla').head(2)
# Out:
#                                Company State/Country
# CIK
# 1728203  Tesla Auto Lease Trust 2018-A            CA
# 1345028   TESLA GROUP HOLDINGS PTY LTD            C3

# %% [markdown]
# ## Get company filings

# %% [markdown]
# Retrieve overview of documents for a given CIK number. We need to paginate here.

# %%
get_company_filings = lambda cik, form_type = '' : get_sec_table('/cgi-bin/browse-edgar', 
              params_provider={'CIK': cik, 'owner': 'exclude', 'action': 'getcompany', 'datab': '', 
                               'start': 0, 'count': 100, 'type': form_type},
              table_provider=table_provider_by_summary('Results', index_col=None),
              pagination_provider=pagination_provider_by_element_start_count(('input',), {'value': 'Next 100'}))

filings = get_company_filings(1318605)

print(filings.shape)
filings.head(3)
# Out:
# (427, 5)
#      Filings                                             Format  \
# 0  SC TO-T/A  /Archives/edgar/data/1318605/00011931251907581...
# 1      S-4/A  /Archives/edgar/data/1318605/00011931251907580...
# 2        425  /Archives/edgar/data/1318605/00011931251907575...
#
#                                          Description Filing Date  \
# 0  [Amend] Tender offer statement by Third PartyA...  2019-03-15
# 1  [Amend] Registration of securities, business c...  2019-03-15
# 2  Prospectuses and communications, business comb...  2019-03-15
#
#                                     File/Film Number
# 0                                                NaN
# 1  /cgi-bin/browse-edgar?action=getcompany&filenu...
# 2                                                NaN

# %% [markdown]
# ## Get company filings using RSS

# %%
def get_company_filings_rss(cik, type_=''):
    has_next = True
    dfs = []
    params = {'CIK': cik, 'type': type_, 'datab': '', 'owner': 'exclude', 'action': 'getcompany',
             'start': 0, 'count': 100, 'output': 'atom'}
    while has_next:
        xml = sess.get(base_url.format('/cgi-bin/browse-edgar'), params=params).text
        df = xmltodict.parse(xml)
        params['start'] += params['count']
        has_next = next((x for x in df['feed']['link'] if x.get('@rel') == 'next'), None) is not None
        dfs.append(df)
    return dfs

def company_filings_rss_to_pandas(filings_rss):
    # Flatten the rss feed based on keys in feed.entry
    return pd.DataFrame([ { '{}_{}'.format(k, ks) : (v[ks] if isinstance(v, dict) else v) \
        for k, v in entry.items() for ks in (v if isinstance(v, dict) else [k]) } \
        for page in filings_rss for entry in page['feed']['entry'] ])

# %%
filings_rss = get_company_filings_rss(1318605)
filings_df = company_filings_rss_to_pandas(filings_rss)

# %%
print(filings_df.shape)

filings_df.head(2)
# Out:
# (427, 26)
#   category_@label      category_@scheme category_@term content_@type  \
# 0       form type  https://www.sec.gov/      SC TO-T/A      text/xml
# 1       form type  https://www.sec.gov/          S-4/A      text/xml
#
#   content_accession-nunber content_act content_amend content_file-number  \
# 0     0001193125-19-075818         NaN       [Amend]                 NaN
# 1     0001193125-19-075806          33       [Amend]          333-229749
#
#                             content_file-number-href content_filing-date  \
# 0                                                NaN          2019-03-15
# 1  https://www.sec.gov/cgi-bin/browse-edgar?actio...          2019-03-15
#
#              ...             content_size content_xbrl_href  \
# 0            ...                   801 KB               NaN
# 1            ...                     2 MB               NaN
#
#                                                id_id  \
# 0  urn:tag:sec.gov,2008:accession-number=00011931...
# 1  urn:tag:sec.gov,2008:accession-number=00011931...
#
#                                           link_@href  link_@rel link_@type  \
# 0  https://www.sec.gov/Archives/edgar/data/131860...  alternate  text/html
# 1  https://www.sec.gov/Archives/edgar/data/131860...  alternate  text/html
#
#                                        summary_#text summary_@type  \
# 0  <b>Filed:</b> 2019-03-15 <b>AccNo:</b> 0001193...          html
# 1  <b>Filed:</b> 2019-03-15 <b>AccNo:</b> 0001193...          html
#
#                                          title_title  \
# 0  SC TO-T/A [Amend]  - Tender offer statement by...
# 1  S-4/A [Amend]  - Registration of securities, b...
#
#              updated_updated
# 0  2019-03-15T08:32:27-04:00
# 1  2019-03-15T08:27:42-04:00
#
# [2 rows x 26 columns]

# %% [markdown]
# ## Get documents for a filing

# %%
get_filing_documents = lambda url, summary = 'Document Format Files' : get_sec_table(url,
              table_provider=table_provider_by_summary(summary, index_col=None),
              pagination_provider=pagination_provider_by_element_start_count(('input',), {'value': 'Next 100'}))

# %%
documents = get_filing_documents('/Archives/edgar/data/1035443/0001047469-19-001263-index.html')

print(documents.shape)
documents.head(3)
# Out:
# (5, 5)
#    Seq  Description                                           Document  \
# 0  1.0        424B5  /Archives/edgar/data/1035443/00010474691900126...
# 1  2.0  G136386.JPG  /Archives/edgar/data/1035443/00010474691900126...
# 2  3.0   G71556.JPG  /Archives/edgar/data/1035443/00010474691900126...
#
#       Type    Size
# 0    424B5  644742
# 1  GRAPHIC   11919
# 2  GRAPHIC   17325

# %%
documents = get_filing_documents('/Archives/edgar/data/1318605/000156459019003165/0001564590-19-003165-index.htm',
                                'Data Files')

print(documents.shape)
documents.head(3)
# Out:
# (6, 5)
#    Seq                                   Description  \
# 0   14                        XBRL INSTANCE DOCUMENT
# 1   15                XBRL TAXONOMY EXTENSION SCHEMA
# 2   16  XBRL TAXONOMY EXTENSION CALCULATION LINKBASE
#
#                                             Document        Type     Size
# 0  /Archives/edgar/data/1318605/00015645901900316...  EX-101.INS  7034413
# 1  /Archives/edgar/data/1318605/00015645901900316...  EX-101.SCH   168083
# 2  /Archives/edgar/data/1318605/00015645901900316...  EX-101.CAL   146696

# %% [markdown]
# ## Get current events

# %%
# See https://www.sec.gov/edgar/searchedgar/currentevents.htm

def get_current_events(days_before=0, form_type=''):
    soup = BeautifulSoup(cach.get(base_url.format('/cgi-bin/current'), 
                            params={'q1': days_before, 'q2': 0, 'q3': form_type}).text)
    pre = soup.find('pre')
    ls = []
    # Remove horizontal rules and replace them with a new line
    # Then split on double spaces after removing links
    # And add in the links separately
    for line in str(pre).replace('<hr>', '\n').replace('<hr/>', '\n').split('\n'):
        bs_line = BeautifulSoup(line)
        clean_line = '  '.join(item.strip() for item in bs_line.find_all(text=True))
        split_line = [ x.strip() for x in clean_line.split('  ') if x.strip() ]
        split_line += [ a.get('href') for a in bs_line.find_all('a') ]
        if not all(x is None for x in split_line): ls.append(split_line)
    colnames = ls[0] + [ 'link_{}'.format(i) for i in range(max(len(l) for l in ls) - len(ls[0])) ]
    return pd.DataFrame(ls[1:], columns=colnames)

# %%
get_current_events().head(3)
# Out:
#    Date Filed  Form CIK Code              Company Name  \
# 0  03-15-2019  10-K  1141807  1ST CONSTITUTION BANCORP
# 1  03-15-2019  10-K   867665    ABRAXAS PETROLEUM CORP
# 2  03-15-2019  10-K   934549      ACACIA RESEARCH CORP
#
#                                               link_0  \
# 0  /Archives/edgar/data/1141807/0001141807-19-000...
# 1  /Archives/edgar/data/867665/0001437749-19-0050...
# 2  /Archives/edgar/data/934549/0000934549-19-0000...
#
#                                        link_1
# 0  browse-edgar?action=getcompany&CIK=1141807
# 1   browse-edgar?action=getcompany&CIK=867665
# 2   browse-edgar?action=getcompany&CIK=934549

# %% [markdown]
# ## Parse XBRL

# %%
doc = get_filing_documents('/Archives/edgar/data/1318605/000156459019003165/0001564590-19-003165-index.htm',
                  'Data Files')
doc.Document.values[0]
# Out:
# '/Archives/edgar/data/1318605/000156459019003165/tsla-20181231.xml'

# %%
from xbrl import XBRLParser, GAAP, GAAPSerializer
from io import StringIO

xml = sess.get(base_url.format(doc.Document.values[0])).text

xbrl_parser = XBRLParser()
xbrl = xbrl_parser.parse(StringIO(xml))

# %%
gaap_obj = xbrl_parser.parseGAAP(xbrl, ignore_errors=2)

# %%
print(gaap_obj.__dict__)
# Out:
# {'assets': 0, 'current_assets': 0, 'non_current_assets': 0, 'liabilities_and_equity': 0, 'liabilities': 0, 'current_liabilities': 0, 'noncurrentLiabilities': 0.0, 'commitments_and_contingencies': 0, 'redeemable_noncontrolling_interest': 0, 'temporary_equity': 0, 'equity': 0, 'equity_attributable_interest': 0, 'equity_attributable_parent': 0, 'stockholders_equity': 0, 'revenue': 0.0, 'cost_of_revenue': 0.0, 'gross_profit': 0, 'costs_and_expenses': 0, 'other_operating_income': 0, 'nonoperating_income_loss': 0, 'interest_and_debt_expense': 0, 'income_before_equity_investments': 0, 'income_from_equity_investments': 0, 'income_tax_expense_benefit': 0, 'net_income_shareholders': 0, 'extraordary_items_gain_loss': 0, 'income_loss': 0, 'preferred_stock_dividends': 0, 'net_income_loss_noncontrolling': 0, 'net_income_parent': 0.0, 'net_income_loss': 0, 'other_comprehensive_income': 0, 'comprehensive_income': 0, 'comprehensive_income_parent': 0, 'comprehensive_income_interest': 0, 'net_cash_flows_operating': 0, 'net_cash_flows_investing': 0, 'net_cash_flows_financing': 0, 'net_cash_flows_operating_continuing': 0.0, 'net_cash_flows_investing_continuing': 0, 'net_cash_flows_financing_continuing': 0, 'net_cash_flows_operating_discontinued': 0, 'net_cash_flows_investing_discontinued': 0, 'net_cash_flows_discontinued': 0, 'common_shares_outstanding': 0, 'common_shares_issued': 0, 'common_shares_authorized': 0, 'noncurrent_liabilities': 0, 'revenues': None, 'operating_expenses': 0, 'operating_income_loss': 0, 'income_continuing_operations_tax': 0, 'income_discontinued_operations': 0, 'net_cash_operating_continuing': 0}

# %%
df = xmltodict.parse(xml)

# %%
print(df['xbrl'].keys())
# Out:
# odict_keys(['@xmlns:utr', '@xmlns:iso4217', '@xmlns', '@xmlns:tsla', '@xmlns:xbrll', '@xmlns:xlink', '@xmlns:nonnum', '@xmlns:num', '@xmlns:xbrldt', '@xmlns:us-types', '@xmlns:srt-types', '@xmlns:us-gaap', '@xmlns:srt', '@xmlns:dei', '@xmlns:country', '@xmlns:currency', '@xmlns:exch', '@xmlns:invest', '@xmlns:stpr', '@xmlns:sic', '@xmlns:naics', '@xmlns:xbrldi', 'xbrll:schemaRef', 'unit', 'context', 'dei:DocumentType', 'dei:AmendmentFlag', 'dei:DocumentPeriodEndDate', 'dei:DocumentFiscalYearFocus', 'dei:DocumentFiscalPeriodFocus', 'dei:TradingSymbol', 'dei:EntityRegistrantName', 'dei:EntityCentralIndexKey', 'dei:CurrentFiscalYearEndDate', 'dei:EntityWellKnownSeasonedIssuer', 'dei:EntityCurrentReportingStatus', 'dei:EntityVoluntaryFilers', 'dei:EntityFilerCategory', 'dei:EntitySmallBusiness', 'dei:EntityEmergingGrowthCompany', 'dei:EntityShellCompany', 'dei:EntityCommonStockSharesOutstanding', 'dei:EntityPublicFloat', 'us-gaap:CashAndCashEquivalentsAtCarryingValue', 'us-gaap:RestrictedCashCurrent', 'us-gaap:AccountsReceivableNetCurrent', 'us-gaap:InventoryNet', 'us-gaap:PrepaidExpenseAndOtherAssetsCurrent', 'us-gaap:AssetsCurrent', 'us-gaap:PropertySubjectToOrAvailableForOperatingLeaseNet', 'us-gaap:PropertyPlantAndEquipmentNet', 'us-gaap:IntangibleAssetsNetExcludingGoodwill', 'us-gaap:Goodwill', 'us-gaap:LongTermAccountsNotesAndLoansReceivableNetNoncurrent', 'us-gaap:RestrictedCashAndCashEquivalentsNoncurrent', 'us-gaap:OtherAssetsNoncurrent', 'us-gaap:Assets', 'us-gaap:AccountsPayableCurrent', 'tsla:AccruedAndOtherCurrentLiabilities', 'us-gaap:ContractWithCustomerLiabilityCurrent', 'tsla:ResaleValueGuaranteesCurrentPortion', 'tsla:CustomerDepositsLiabilitiesCurrent', 'us-gaap:LongTermDebtAndCapitalLeaseObligationsCurrent', 'us-gaap:DueToRelatedPartiesCurrent', 'us-gaap:LiabilitiesCurrent', 'us-gaap:LongTermDebtAndCapitalLeaseObligations', 'us-gaap:ContractWithCustomerLiabilityNoncurrent', 'tsla:ResaleValueGuaranteesNoncurrentPortion', 'us-gaap:OtherLiabilitiesNoncurrent', 'us-gaap:Liabilities', 'us-gaap:CommitmentsAndContingencies', 'us-gaap:RedeemableNoncontrollingInterestEquityCarryingAmount', 'us-gaap:TemporaryEquityCarryingAmountAttributableToParent', 'us-gaap:PreferredStockValue', 'us-gaap:CommonStockValue', 'us-gaap:AdditionalPaidInCapitalCommonStock', 'us-gaap:AccumulatedOtherComprehensiveIncomeLossNetOfTax', 'us-gaap:RetainedEarningsAccumulatedDeficit', 'us-gaap:StockholdersEquity', 'us-gaap:MinorityInterest', 'us-gaap:LiabilitiesAndStockholdersEquity', 'us-gaap:PreferredStockParOrStatedValuePerShare', 'us-gaap:PreferredStockSharesAuthorized', 'us-gaap:PreferredStockSharesIssued', 'us-gaap:PreferredStockSharesOutstanding', 'us-gaap:CommonStockParOrStatedValuePerShare', 'us-gaap:CommonStockSharesAuthorized', 'us-gaap:CommonStockSharesIssued', 'us-gaap:CommonStockSharesOutstanding', 'us-gaap:RevenueFromContractWithCustomerExcludingAssessedTax', 'us-gaap:OperatingLeasesIncomeStatementLeaseRevenue', 'tsla:SalesRevenueAutomotive', 'tsla:SalesRevenueServicesAndOtherNet', 'us-gaap:Revenues', 'us-gaap:CostOfGoodsAndServicesSold', 'tsla:CostOfAutomotiveLeasing', 'tsla:CostOfRevenuesAutomotive', 'tsla:CostOfServicesAndOther', 'us-gaap:CostOfRevenue', 'us-gaap:GrossProfit', 'us-gaap:ResearchAndDevelopmentExpense', 'us-gaap:SellingGeneralAndAdministrativeExpense', 'tsla:RestructuringAndOtherExpenses', 'us-gaap:OperatingExpenses', 'us-gaap:OperatingIncomeLoss', 'us-gaap:InvestmentIncomeInterest', 'us-gaap:InterestExpense', 'us-gaap:OtherNonoperatingIncomeExpense', 'us-gaap:IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest', 'us-gaap:IncomeTaxExpenseBenefit', 'us-gaap:ProfitLoss', 'us-gaap:NetIncomeLossAttributableToNoncontrollingInterest', 'us-gaap:NetIncomeLoss', 'us-gaap:EarningsPerShareBasic', 'us-gaap:EarningsPerShareDiluted', 'us-gaap:WeightedAverageNumberOfSharesOutstandingBasic', 'us-gaap:WeightedAverageNumberOfDilutedSharesOutstanding', 'us-gaap:OtherComprehensiveIncomeUnrealizedGa ...

# %% [markdown]
# # Downloading and saving SEC documents

# %%
def download_sec_document(doc_link, directory='forms/'):
    contents = clean_sec_content(cach.get(base_url.format(doc_link)).content)
    name = slugify(doc_link)
    with open(directory + name, 'w') as f: f.write(contents)

# %%
# We'll scrape a collection of 424B5 forms

num_days = 5

for p in range(0, num_days):
    print('Scraping day-page:', p)
    forms = get_current_events(p, '424B5')
    for link in forms['link_0']:
        docs = get_filing_documents(base_url.format(link))
        doc_link = docs.loc[docs.Type == '424B5', 'Document'].values[0]
        download_sec_document(doc_link)
# Out:
# Scraping day-page: 0
# Scraping day-page: 1
# Scraping day-page: 2
# Scraping day-page: 3
# Scraping day-page: 4

# %% [markdown]
# # Extracting information

# %% [markdown]
# ## Cleaning

# %%
def read_html(file):
    with open(file, 'r') as f: return f.read()

# %%
def clean_html(html):
    soup = BeautifulSoup(html)
    if not soup.find('p'):
        for div in soup.find_all('div'):
            div.name = 'p'
    for b in soup.find_all('b'):
        b.name = 'strong'
    for f in soup.find_all('font', style=re.compile('font-weight:\s*bold')):
        f.name = 'strong'
    for footer in soup.find_all(class_=['header', 'footer']): 
        try: footer.decompose()
        except: pass
    san = sanitize(str(soup), CustomCleaner)
    soup = BeautifulSoup(san)
    def decompose_parent(el, parent='p', not_grandparent='table'):
        try:
            parent = el.find_parent(parent)
        except: parent = None
        if not parent: return
        grandparent = parent.find_parent('table')
        if grandparent: return
        parent.decompose()
    for el in soup.find_all(text=lambda x: 'table of contents' == str(x).lower().strip()):
        decompose_parent(el, 'a')
    for el in soup.find_all(text=re.compile(r'^\s*S\-(\d+|[ivxlcdm]+)\s*$')): 
        decompose_parent(el, 'p')
    for el in soup.find_all(text=re.compile(r'^\s*\d+\s*$')): 
        decompose_parent(el, 'p')
    return soup

# %%
content = read_html('forms/-archives-edgar-data-319201-000119312519074988-d706100d424b5.htm')
cleaned = clean_html(content)

# %%
window(str(cleaned))
# Out:
# <script type="text/javascript">var win = window.open("", "", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<html><body><p>\n424B5\n1\nd706100d424b5.htm\n424B5\n\n424B5\n</p><h5 align="left"></h5>\n<p align="right"><strong>Filed Pursuant to Rule 424(b)(5) <br/> File No. 333-222827 <br/> </strong></p>\n<table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td width="36%"></td>\n<td valign="bottom" width="3%"></td>\n<td></td>\n<td valign="bottom" width="1%"></td>\n<td></td>\n<td valign="bottom" width="2%"></td>\n<td></td>\n<td valign="bottom" width="3%"></td>\n<td></td></tr>\n<tr>\n<td colspan="9" valign="bottom"> <p align="center"><strong>CALCULATION OF REGISTRATION FEE</strong></p>\n</td></tr>\n<tr>\n<td colspan="9" valign="bottom"> </td></tr>\n<tr>\n<td align="center" valign="bottom"><strong>Title of Each Class of<br/>Security to be Registed</strong></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"> <p align="center"><strong>Amount    </strong></p>\n<p align="center"><strong>to be    </strong></p>\n<p align="center"><strong>Registered    </strong></p></td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom"><strong>Proposed    <br/>Maximum    <br/>Offering Price    <br/>per Unit    </strong></td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom"> <p align="center"><strong>Proposed    </strong></p>\n<p align="center"><strong>Maximum    </strong></p>\n<p align="center"><strong>Aggregate    </strong></p>\n<p align="center"><strong>Offering Price</strong></p></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"><strong>Amount of<br/>Registration Fee (1)</strong></td></tr>\n<tr>\n<td valign="top"> <p>4.10% Senior Notes due 2029</p></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$800,000,000.00    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">99.522%    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">$796,176,000.00    </td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$96,496.54</td></tr>\n<tr>\n<td valign="top"> <p>5.00% Senior Notes due 2049</p></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$400,000,000.00    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">99.278%    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">$397,112,000.00    </td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$48,129.98</td></tr>\n<tr>\n<td valign="top"> </td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"><strong>$1,200,000,000.00    </strong></td>\n<td valign="bottom"> </td>\n<td valign="bottom"> </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom"><strong>$1,193,288,000.00    </strong></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"><strong>$144,626.52</strong></td></tr>\n<tr>\n<td colspan="9" valign="bottom"> </td></tr>\n<tr>\n<td colspan="9" valign="bottom"> </td></tr>\n</table>\n<table border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td align="left" valign="top" width="4%">(1)</td>\n<td align="left" valign="top"> <p align="left">Calculated in accordance with Rule 457(r) of the Securities Act of 1933, as amended. </p></td></tr></table>\n<table border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td align="left" valign="top" width="4%"></td></tr></table>\n<h5 align="left"></h5>\n<p><strong>PROSPECTUS SUPPLEMENT </strong></p> <p><strong>(To prospectus dated February 1, 2018) </strong></p> <p align="center"><strong><i>$1,200,000,000 </i></strong></p>\n<p align="center"><strong>KLA-Tencor Corporation ...

# %% [markdown]
# ## Basic offering summary extraction

# %%
content = read_html('forms/-archives-edgar-data-319201-000119312519074988-d706100d424b5.htm')
cleaned = clean_html(content)

# %%
window(str(cleaned))
# Out:
# <script type="text/javascript">var win = window.open("", "", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<html><body><p>\n424B5\n1\nd706100d424b5.htm\n424B5\n\n424B5\n</p><h5 align="left"></h5>\n<p align="right"><strong>Filed Pursuant to Rule 424(b)(5) <br/> File No. 333-222827 <br/> </strong></p>\n<table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td width="36%"></td>\n<td valign="bottom" width="3%"></td>\n<td></td>\n<td valign="bottom" width="1%"></td>\n<td></td>\n<td valign="bottom" width="2%"></td>\n<td></td>\n<td valign="bottom" width="3%"></td>\n<td></td></tr>\n<tr>\n<td colspan="9" valign="bottom"> <p align="center"><strong>CALCULATION OF REGISTRATION FEE</strong></p>\n</td></tr>\n<tr>\n<td colspan="9" valign="bottom"> </td></tr>\n<tr>\n<td align="center" valign="bottom"><strong>Title of Each Class of<br/>Security to be Registed</strong></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"> <p align="center"><strong>Amount    </strong></p>\n<p align="center"><strong>to be    </strong></p>\n<p align="center"><strong>Registered    </strong></p></td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom"><strong>Proposed    <br/>Maximum    <br/>Offering Price    <br/>per Unit    </strong></td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom"> <p align="center"><strong>Proposed    </strong></p>\n<p align="center"><strong>Maximum    </strong></p>\n<p align="center"><strong>Aggregate    </strong></p>\n<p align="center"><strong>Offering Price</strong></p></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"><strong>Amount of<br/>Registration Fee (1)</strong></td></tr>\n<tr>\n<td valign="top"> <p>4.10% Senior Notes due 2029</p></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$800,000,000.00    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">99.522%    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">$796,176,000.00    </td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$96,496.54</td></tr>\n<tr>\n<td valign="top"> <p>5.00% Senior Notes due 2049</p></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$400,000,000.00    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">99.278%    </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom">$397,112,000.00    </td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom">$48,129.98</td></tr>\n<tr>\n<td valign="top"> </td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"><strong>$1,200,000,000.00    </strong></td>\n<td valign="bottom"> </td>\n<td valign="bottom"> </td>\n<td valign="bottom"> </td>\n<td align="center" nowrap="" valign="bottom"><strong>$1,193,288,000.00    </strong></td>\n<td valign="bottom">  </td>\n<td align="center" nowrap="" valign="bottom"><strong>$144,626.52</strong></td></tr>\n<tr>\n<td colspan="9" valign="bottom"> </td></tr>\n<tr>\n<td colspan="9" valign="bottom"> </td></tr>\n</table>\n<table border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td align="left" valign="top" width="4%">(1)</td>\n<td align="left" valign="top"> <p align="left">Calculated in accordance with Rule 457(r) of the Securities Act of 1933, as amended. </p></td></tr></table>\n<table border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td align="left" valign="top" width="4%"></td></tr></table>\n<h5 align="left"></h5>\n<p><strong>PROSPECTUS SUPPLEMENT </strong></p> <p><strong>(To prospectus dated February 1, 2018) </strong></p> <p align="center"><strong><i>$1,200,000,000 </i></strong></p>\n<p align="center"><strong>KLA-Tencor Corporation ...

# %%
def extract_dual_tables(soup):
    dualrows = []
    for tr in soup.select("table tr"):
        row = [td.text.strip() for td in tr.find_all('td')]
        if len(row) != 2:
            continue
        if row[1].strip() == '':
            continue
        if all([row[x] == '' for x in range(0, len(row)-1)]):
            if len(dualrows) > 0 and len(row) == len(dualrows[-1]):
                dualrows[-1][-1] += ' ' + row[-1]
        else:
            dualrows.append(row)
    return dualrows

# %%
extract_dual_tables(cleaned)
# Out:
# [['(1)',
#   'Calculated in accordance with Rule 457(r) of the Securities Act of 1933, as amended.'],
#  ['(1)',
#   'Plus accrued interest from March 20, 2019, if settlement occurs after that date'],
#  ['Issuer', 'KLA-Tencor Corporation, a Delaware corporation.'],
#  ['Securities offered',
#   '$800,000,000\xa0aggregate principal amount of 2029\xa0notes and $400,000,000 aggregate principal amount of 2049\xa0notes.'],
#  ['Maturity date',
#   'The 2029\xa0notes will mature on March 15, 2029\xa0and the 2049\xa0notes will mature on\xa0March 15, 2049.'],
#  ['Interest payment date',
#   'March 15 and\xa0September 15 of each year, beginning\xa0September 15, 2019.'],
#  ['Ranking',
#   'The notes will be our unsecured senior obligations and will: As of December\xa031, 2018, we had $2.2\xa0billion of indebtedness for borrowed money, which includes current and non-current\nliabilities, none of which was secured indebtedness, and our subsidiaries had $526.3\xa0million of liabilities (including trade payables but excluding intercompany obligations and liabilities of a type not required to be reflected on a balance\nsheet of such subsidiaries in accordance with U.S. generally accepted accounting principles (“GAAP”)) to which the notes would have been structurally subordinated. After giving effect to the acquisition of Orbotech, the issuance of the\nnotes offered hereby and our borrowing of $900.0\xa0million under our Revolving Credit Facility as partial funding of our acquisition of Orbotech based on the assumptions set forth under “Pro forma condensed combined financial\ninformation” and “Capitalization,” on a pro forma as adjusted basis, our total indebtedness for borrowed money, would have been $3.5\xa0billion as of December\xa031, 2018.'],
#  ['Further issuances',
#   'We may create and issue additional series of notes under the indenture governing the notes. To the extent we do so, the separate series of notes will not vote together as a single series on any matters.\nWe may also create and issue additional notes of any series offered hereby equal in rank to the notes of such series in all respects (or in all respects except for the issue price, the payment of interest accruing prior to the issue date of such\nadditional notes, or the first payment of interest following the issue date of such additional notes) so that the additional notes may be consolidated and form a single series with the notes of such series, and have the same terms as to status,\nredemption and otherwise as the notes of such series. See “Description of the notes — Principal, maturity and interest.”'],
#  ['Guarantees',
#   'The notes will not be guaranteed by any of our subsidiaries.'],
#  ['Optional redemption',
#   'We may redeem the notes in whole or in part at any time at the applicable redemption prices. See “Description of the notes — Redemption — Optional redemption.”'],
#  ['Repurchase upon change of control triggering event',
#   'Upon the occurrence of a Change of Control Triggering Event (as defined in this prospectus supplement), we will be required to make an offer to purchase the notes at a price equal to 101% of their\nprincipal amount plus accrued and unpaid interest to the date of repurchase. See “Description of the notes — Repurchase upon change of control triggering event.”'],
#  ['Listing',
#   'The notes will not be listed on any securities exchange or automated quotation system.'],
#  ['No prior market',
#   'Each series of notes will be a new issue of securities for which there is currently no market. Although the underwriters have informed us that they intend to make a market in the notes, they are not\nobligated to do so, and they may discontinue market making activities at any time without notice. Accordingly, we cannot assure you that a liquid market for the notes will develop or be maintained.'],
#  ['Use of proceeds',
#   'We estimate the net proceeds from the sale of the notes will be approximately $1.18\xa0billion after deducting the estimated underwriting discounts and estimated offering expenses. We intend to use the\nnet proceeds of this offering to partially refinance our existing debt, including borrowings under the Credit Agreement, to repurchase shares, and for general corporate purposes.'],
#  ['Governing Law', 'New York.'],
#  ['Trustee', 'Wells Fargo Bank, National Association.'],
#  ['Risk factors',
#   'You should carefully consider, along with the other information contained or incorporated by reference in this prospectus supplement and the accompanying prospectus, the specific factors set forth in this\nprospectus supplement under “Risk factors” before deciding whether to invest in the notes.'],
#  ['Conflicts of Interest',
#   'Affiliates of J.P. Morgan Securities LLC, Citigroup Global Markets Inc., Merrill Lynch, Pierce, Fenner & Smith Incorporated, MUFG Securities Americas Inc., Wells Fargo Securities, LLC, BB&T\nCapital Markets, a division of BB&T Securities, LLC, Scotia Capital (USA) Inc., SunTrust Robinson Humphrey, Inc., and U.S. Bancorp Investments, Inc. will receive at least 5% of the net proceeds of this offering in connection with the repayment\nof a portion of our outstanding borrowings under our Credit Agreement. See “Use of proceeds.” Accordingly, this offering is being made in compliance with the requirements of Rule 5121 of FINRA (as defined herein). Because the notes to be\noffered will be rated investment grade, pursuant to Rule 5121, the appointment of a qualified independent underwriter is not necessary. J.P. Morgan Securities LLC, Citigroup Global Markets Inc., Merrill Lynch, Pierce, Fenner & Smith\nIncorporated, MUFG Securities Americas Inc., and Wells Fargo Securities, LLC will not confirm sales of the notes to any account over which they exercise discretionary authority without the prior written approval of the customer.'],
#  ['(1)',
#   'Excludes the principal amount of $250.0\xa0million, reflecting the current portion of long-term debt.'],
#  ['(2)',
#   'Balance reflects the principal amount and not the GAAP carrying value, which includes unamortized discount and debt issuance costs of $11.6\xa0million\nin the aggregate.'],
#  ['(3)',
#   'The pro forma as adjusted amount does not reflect any debt discounts or other capitalized debt issuance costs and reflects the principal amounts\noutstanding.'],
#  ['(4)',
#   'On February\xa019, 2019, we borrowed $900.0\xa0million under the Revolving Credit Facility as partial funding of our acquisition of Orbotech.'],
#  ['(1)',
#   'Represents the total cash paid to Orbotech shareholders for outstanding Orbotech shares as Cash Consideration (“Cash Consideration”). The\namount is based on 48,943,593 Orbotech Shares issued and outstanding as of February\xa020, 2019 and Cash Consideration of $38.86 per Orbotec share.'],
#  ['(2)',
#   'Represents the fair value of 12,235,885 shares of KLA common stock issued to Orbotech shareholders for outstanding Orbotech shares as Stock\nConsideration (“Stock Consideration” and, together with the Cash Consideration, “Merger Consideration”). The amount is based on 48,943,593 Orbotech shares issued and outstanding as of February\xa020, 2019, the Closing Date of\nthe Merger, Stock Consideration of 0.25 of a share of KLA common stock per Orbotech share, and the closing KLA common stock price on February\xa019, 2019, the date immediately preceding the Closing Date of the Merger, of $108.26.'],
#  ['(3)',
#   'Includes the Cash Consideration of $9\xa0million for the net settlement of vested and unsettled Orbotech stock options, and $1\xa0million for the\ntotal of accelerated vesting of restricted stock unit awards and fractional shares related to common stock as of February\xa020, 2019.'],
#  ['(4)',
#   'Represents the fair value of share of KLA common stock issued to settle the intrinsic value remaining after the Cash Consideration settlement\nrepresenting approximately 56,719 Orbotech stock options vested and unsettled as of February\xa020, 2019. The amount is based on the Stock Consideration and the closing KLA common stock price on February\xa019, 2019 of $108.26.'],
#  ['(5)',
#   'Represents the fair value of KLA’s replacement equity awards for pre-combination services. Pursuant to the\nterms of the Merger Agreement, Orbotech’s outstanding equity awards that are unvested as of the Closing Date will be replaced by KLA equity awards with the same terms and conditions. A portion of the fair value of KLA’s replacement equity\nawards issued represents consideration transferred, while a portion represents post-combination compensation expense based on the vesting terms of the equity awards.']]

# %%
# Warning: the text parameter uses string internally and doesn't work in case of nested tags!
cleaned.find('p', text=re.compile(r'OFF'))

# %%
def match_by_name_and_regex(name, regex, lowercase=True):
    return lambda el : el.name == name and re.search(regex, el.text.lower() if lowercase else el.text) is not None

# %%
def get_offering_header_candidates(soup):
    return soup.find_all(match_by_name_and_regex('p', r'\s*offering\s*$'))

def get_after_offering_header_tables(header):
    tables = ''
    nextSibling = header.nextSibling
    table_seen = False
    while True:
        if nextSibling is None:
            break
        if type(nextSibling) == NavigableString:   
            if table_seen and str(nextSibling).strip() != '': break
            nextSibling = nextSibling.nextSibling
            continue
        if nextSibling.name != 'table':
            if table_seen and nextSibling.get_text(strip=True) != '': break
            nextSibling = nextSibling.nextSibling
            continue
        table_seen = True
        tables += str(nextSibling)
        if not nextSibling.nextSibling:
            print(nextSibling)
            print(nextSibling.nextSibling)
        nextSibling = nextSibling.nextSibling
    return tables

def extract_offering(soup):
    for header in get_offering_header_candidates(soup):
        tables = get_after_offering_header_tables(header)
        if tables:
            return extract_dual_tables(BeautifulSoup(tables))

        
extract_offering(cleaned)
# Out:
# [['Issuer', 'KLA-Tencor Corporation, a Delaware corporation.'],
#  ['Securities offered',
#   '$800,000,000\xa0aggregate principal amount of 2029\xa0notes and $400,000,000 aggregate principal amount of 2049\xa0notes.'],
#  ['Maturity date',
#   'The 2029\xa0notes will mature on March 15, 2029\xa0and the 2049\xa0notes will mature on\xa0March 15, 2049.'],
#  ['Interest payment date',
#   'March 15 and\xa0September 15 of each year, beginning\xa0September 15, 2019.'],
#  ['Ranking',
#   'The notes will be our unsecured senior obligations and will: As of December\xa031, 2018, we had $2.2\xa0billion of indebtedness for borrowed money, which includes current and non-current\nliabilities, none of which was secured indebtedness, and our subsidiaries had $526.3\xa0million of liabilities (including trade payables but excluding intercompany obligations and liabilities of a type not required to be reflected on a balance\nsheet of such subsidiaries in accordance with U.S. generally accepted accounting principles (“GAAP”)) to which the notes would have been structurally subordinated. After giving effect to the acquisition of Orbotech, the issuance of the\nnotes offered hereby and our borrowing of $900.0\xa0million under our Revolving Credit Facility as partial funding of our acquisition of Orbotech based on the assumptions set forth under “Pro forma condensed combined financial\ninformation” and “Capitalization,” on a pro forma as adjusted basis, our total indebtedness for borrowed money, would have been $3.5\xa0billion as of December\xa031, 2018.'],
#  ['Further issuances',
#   'We may create and issue additional series of notes under the indenture governing the notes. To the extent we do so, the separate series of notes will not vote together as a single series on any matters.\nWe may also create and issue additional notes of any series offered hereby equal in rank to the notes of such series in all respects (or in all respects except for the issue price, the payment of interest accruing prior to the issue date of such\nadditional notes, or the first payment of interest following the issue date of such additional notes) so that the additional notes may be consolidated and form a single series with the notes of such series, and have the same terms as to status,\nredemption and otherwise as the notes of such series. See “Description of the notes — Principal, maturity and interest.”'],
#  ['Guarantees',
#   'The notes will not be guaranteed by any of our subsidiaries.'],
#  ['Optional redemption',
#   'We may redeem the notes in whole or in part at any time at the applicable redemption prices. See “Description of the notes — Redemption — Optional redemption.”'],
#  ['Repurchase upon change of control triggering event',
#   'Upon the occurrence of a Change of Control Triggering Event (as defined in this prospectus supplement), we will be required to make an offer to purchase the notes at a price equal to 101% of their\nprincipal amount plus accrued and unpaid interest to the date of repurchase. See “Description of the notes — Repurchase upon change of control triggering event.”'],
#  ['Listing',
#   'The notes will not be listed on any securities exchange or automated quotation system.'],
#  ['No prior market',
#   'Each series of notes will be a new issue of securities for which there is currently no market. Although the underwriters have informed us that they intend to make a market in the notes, they are not\nobligated to do so, and they may discontinue market making activities at any time without notice. Accordingly, we cannot assure you that a liquid market for the notes will develop or be maintained.'],
#  ['Use of proceeds',
#   'We estimate the net proceeds from the sale of the notes will be approximately $1.18\xa0billion after deducting the estimated underwriting discounts and estimated offering expenses. We intend to use the\nnet proceeds of this offering to partially refinance our existing debt, including borrowings under the Credit Agreement, to repurchase shares, and for general corporate purposes.'],
#  ['Governing Law', 'New York.'],
#  ['Trustee', 'Wells Fargo Bank, National Association.'],
#  ['Risk factors',
#   'You should carefully consider, along with the other information contained or incorporated by reference in this prospectus supplement and the accompanying prospectus, the specific factors set forth in this\nprospectus supplement under “Risk factors” before deciding whether to invest in the notes.'],
#  ['Conflicts of Interest',
#   'Affiliates of J.P. Morgan Securities LLC, Citigroup Global Markets Inc., Merrill Lynch, Pierce, Fenner & Smith Incorporated, MUFG Securities Americas Inc., Wells Fargo Securities, LLC, BB&T\nCapital Markets, a division of BB&T Securities, LLC, Scotia Capital (USA) Inc., SunTrust Robinson Humphrey, Inc., and U.S. Bancorp Investments, Inc. will receive at least 5% of the net proceeds of this offering in connection with the repayment\nof a portion of our outstanding borrowings under our Credit Agreement. See “Use of proceeds.” Accordingly, this offering is being made in compliance with the requirements of Rule 5121 of FINRA (as defined herein). Because the notes to be\noffered will be rated investment grade, pursuant to Rule 5121, the appointment of a qualified independent underwriter is not necessary. J.P. Morgan Securities LLC, Citigroup Global Markets Inc., Merrill Lynch, Pierce, Fenner & Smith\nIncorporated, MUFG Securities Americas Inc., and Wells Fargo Securities, LLC will not confirm sales of the notes to any account over which they exercise discretionary authority without the prior written approval of the customer.']]

# %% [markdown]
# ## Spacy

# %%
import spacy
from spacy import displacy
import en_core_web_sm # python -m spacy download en

nlp = en_core_web_sm.load()

# %%
content = read_html('forms/-archives-edgar-data-319201-000119312519074988-d706100d424b5.htm')
cleaned = clean_html(content)

offering_table = extract_offering(cleaned)

# %%
for h, t in offering_table:
    doc = nlp(t)
    pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('KLA-Tencor Corporation', 'ORG'), ('Delaware', 'GPE')]
# [('800,000,000', 'MONEY'),
#  ('\xa0', 'ORG'),
#  ('2029', 'DATE'),
#  ('\xa0', 'ORG'),
#  ('400,000,000', 'MONEY'),
#  ('2049', 'CARDINAL'),
#  ('\xa0', 'ORG')]
# [('2029', 'DATE'),
#  ('\xa0', 'ORG'),
#  ('March 15, 2029\xa0', 'DATE'),
#  ('\xa0', 'PERSON'),
#  ('\xa0March 15, 2049', 'DATE')]
# [('March 15', 'DATE'),
#  ('September 15 of each year', 'DATE'),
#  ('\xa0', 'PERSON'),
#  ('September 15, 2019', 'DATE')]
# [('December\xa031, 2018', 'DATE'),
#  ('2.2', 'MONEY'),
#  ('\n', 'GPE'),
#  ('526.3', 'MONEY'),
#  ('\xa0million', 'CARDINAL'),
#  ('\n', 'GPE'),
#  ('U.S.', 'GPE'),
#  ('Orbotech', 'ORG'),
#  ('\n', 'GPE'),
#  ('$900.0\xa0million', 'MONEY'),
#  ('Revolving Credit Facility', 'ORG'),
#  ('Orbotech', 'ORG'),
#  ('Pro', 'ORG'),
#  ('\n', 'GPE'),
#  ('Capitalization', 'WORK_OF_ART'),
#  ('$3.5\xa0billion', 'MONEY'),
#  ('December\xa031, 2018', 'DATE')]
# [('\n', 'GPE'),
#  ('\n', 'GPE'),
#  ('first', 'ORDINAL'),
#  ('\n', 'GPE'),
#  ('— Principal', 'PERSON')]
# []
# []
# [('101%', 'PERCENT'), ('\n', 'GPE')]
# []
# [('\n', 'GPE')]
# [('approximately $1.18\xa0billion', 'MONEY'),
#  ('\n', 'GPE'),
#  ('the Credit Agreement', 'LAW')]
# [('New York', 'GPE')]
# [('Wells Fargo Bank', 'ORG'), ('National Association', 'ORG')]
# [('\n', 'GPE')]
# [('J.P. Morgan Securities LLC', 'ORG'),
#  ('Citigroup Global Markets Inc.', 'ORG'),
#  ('Merrill Lynch', 'ORG'),
#  ('Pierce', 'ORG'),
#  ('Fenner & Smith Incorporated', 'ORG'),
#  ('MUFG Securities Americas Inc.', 'ORG'),
#  ('Wells Fargo Securities', 'ORG'),
#  ('LLC', 'ORG'),
#  ('BB&T\nCapital Markets', 'ORG'),
#  ('BB&T Securities', 'ORG'),
#  ('LLC, Scotia Capital (USA) Inc.', 'ORG'),
#  ('SunTrust Robinson Humphrey, Inc.', 'ORG'),
#  ('U.S. Bancorp Investments, Inc.', 'ORG'),
#  ('at least 5%', 'PERCENT'),
#  ('\n', 'GPE'),
#  ('our Credit Agreement', 'LAW'),
#  ('Rule 5121', 'EVENT'),
#  ('FINRA', 'PERSON'),
#  ('\n', 'GPE'),
#  ('5121', 'DATE'),
#  ('J.P. Morgan Securities LLC', 'ORG'),
#  ('Citigroup Global Markets Inc.', 'ORG'),
#  ('Merrill Lynch', 'ORG'),
#  ('Pierce,', 'ORG'),
#  ('Fenner & Smith\n', 'ORG'),
#  ('MUFG Securities Americas Inc.', 'ORG'),
#  ('Wells Fargo Securities', 'ORG'),
#  ('LLC', 'ORG')]

# %%
for h, t in offering_table:
    doc = nlp(t)
    print('================= ' + h + ' ==============')
    displacy.render(doc, jupyter=True, style='ent')
# Out:
# ================= Issuer ==============
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     KLA-Tencor Corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Delaware
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  corporation.</div>
# ================= Securities offered ==============
# <div class="entities" style="line-height: 2.5">$
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     800,000,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# aggregate principal amount of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2029
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# notes and $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     400,000,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  aggregate principal amount of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2049
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# notes.</div>
# ================= Maturity date ==============
# <div class="entities" style="line-height: 2.5">The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2029
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# notes will mature on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     March 15, 2029
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# and the 2049
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# notes will mature on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#      March 15, 2049
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>
# ================= Interest payment date ==============
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     March 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     September 15 of each year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , beginning
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     September 15, 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>
# ================= Ranking ==============
# <div class="entities" style="line-height: 2.5">The notes will be our unsecured senior obligations and will: As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     December 31, 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , we had $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  billion of indebtedness for borrowed money, which includes current and non-current
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# liabilities, none of which was secured indebtedness, and our subsidiaries had $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     526.3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#      million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of liabilities (including trade payables but excluding intercompany obligations and liabilities of a type not required to be reflected on a balance
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# sheet of such subsidiaries in accordance with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  generally accepted accounting principles (“GAAP”)) to which the notes would have been structurally subordinated. After giving effect to the acquisition of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Orbotech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the issuance of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# notes offered hereby and our borrowing of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     $900.0 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  under our
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Revolving Credit Facility
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as partial funding of our acquisition of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Orbotech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  based on the assumptions set forth under “
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  forma condensed combined financial
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# information” and “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Capitalization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ,” on a pro forma as adjusted basis, our total indebtedness for borrowed money, would have been
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     $3.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     December 31, 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>
# ================= Further issuances ==============
# <div class="entities" style="line-height: 2.5">We may create and issue additional series of notes under the indenture governing the notes. To the extent we do so, the separate series of notes will not vote together as a single series on any matters.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# We may also create and issue additional notes of any series offered hereby equal in rank to the notes of such series in all respects (or in all respects except for the issue price, the payment of interest accruing prior to the issue date of such
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# additional notes, or the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  payment of interest following the issue date of such additional notes) so that the additional notes may be consolidated and form a single series with the notes of such series, and have the same terms as to status,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# redemption and otherwise as the notes of such series. See “Description of the notes
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     — Principal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , maturity and interest.”</div>
# ================= Guarantees ==============
# C:\Users\Seppe\Anaconda3\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5">The notes will not be guaranteed by any of our subsidiaries.</div>
# ================= Optional redemption ==============
# C:\Users\Seppe\Anaconda3\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5">We may redeem the notes in whole or in part at any time at the applicable redemption prices. See “Description of the notes — Redemption — Optional redemption.”</div>
# ================= Repurchase upon change of control triggering event ==============
# <div class="entities" style="line-height: 2.5">Upon the occurrence of a Change of Control Triggering Event (as defined in this prospectus supplement), we will be required to make an offer to purchase the notes at a price equal to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     101%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of their
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# principal amount plus accrued and unpaid interest to the date of repurchase. See “Description of the notes — Repurchase upon change of control triggering event.”</div>
# ================= Listing ==============
# C:\Users\Seppe\Anaconda3\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5">The notes will not be listed on any securities exchange or automated quotation system.</div>
# ================= No prior market ==============
# <div class="entities" style="line-height: 2.5">Each series of notes will be a new issue of securities for which there is currently no market. Although the underwriters have informed us that they intend to make a market in the notes, they are not
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# obligated to do so, and they may discontinue market making activities at any time without notice. Accordingly, we cannot assure you that a liquid market for the notes will develop or be maintained.</div>
# ================= Use of proceeds ==============
# <div class="entities" style="line-height: 2.5">We estimate the net proceeds from the sale of the notes will be
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     approximately $1.18 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  after deducting the estimated underwriting discounts and estimated offering expenses. We intend to use the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# net proceeds of this offering to partially refinance our existing debt, including borrowings under
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Credit Agreement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# , to repurchase shares, and for general corporate purposes.</div>
# ================= Governing Law ==============
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div>
# ================= Trustee ==============
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Wells Fargo Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     National Association
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div>
# ================= Risk factors ==============
# <div class="entities" style="line-height: 2.5">You should carefully consider, along with the other information contained or incorporated by reference in this prospectus supplement and the accompanying prospectus, the specific factors set forth in this
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# prospectus supplement under “Risk factors” before deciding whether to invest in the notes.</div>
# ================= Conflicts of Interest ==============
# <div class="entities" style="line-height: 2.5">Affiliates of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     J.P. Morgan Securities LLC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Citigroup Global Markets Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Merrill Lynch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Pierce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Fenner & Smith Incorporated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     MUFG Securities Americas Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Wells Fargo Securities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     LLC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BB&T
# Capital Markets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a division of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BB&T Securities
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     LLC, Scotia Capital (USA) Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     SunTrust Robinson Humphrey, Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     U.S. Bancorp Investments, Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will receive
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     at least 5%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of the net proceeds of this offering in connection with the repayment
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# of a portion of our outstanding borrowings under
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     our Credit Agreement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# . See “Use of proceeds.” Accordingly, this offering is being made in compliance with the requirements of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rule 5121
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     FINRA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (as defined herein). Because the notes to be
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; ve

# %% [markdown]
# See https://prodi.gy/ for a way how we could relatively easily train on SEC entities.

# %% [markdown]
# ## Iterating over files

# %%
all_combinations = []

for html_file in glob('forms/*.htm'):
    print(html_file)
    content = read_html(html_file)
    cleaned = clean_html(content)
    off = extract_offering(cleaned)
    if off:
        all_combinations += off
# Out:
# forms\-archives-edgar-data-1035443-000104746919001118-a2237996z424b5.htm
# forms\-archives-edgar-data-1035443-000104746919001263-a2238051z424b5.htm
# forms\-archives-edgar-data-1042046-000114036119004640-s002575x1_424b5.htm
# forms\-archives-edgar-data-1042046-000114036119004798-s002575x3_424b5.htm
# forms\-archives-edgar-data-1044378-000156459019008062-bioc-424b5.htm
# forms\-archives-edgar-data-1053507-000119312519071425-d636720d424b5.htm
# forms\-archives-edgar-data-1066194-000104746919001242-a2238081z424b5.htm
# forms\-archives-edgar-data-1090727-000119312519072761-d704691d424b5.htm
# forms\-archives-edgar-data-1090727-000119312519075162-d704691d424b5.htm
# forms\-archives-edgar-data-1099590-000114036119004743-s002725x2_424b5.htm
# forms\-archives-edgar-data-1099590-000114036119004897-s002725x5_424b5.htm
# forms\-archives-edgar-data-1126530-000092963819000366-a73006_424b5.htm
# forms\-archives-edgar-data-1133818-000114420419013719-tv516099_424b5.htm
# forms\-archives-edgar-data-1169987-000119312519073308-d713583d424b5.htm
# forms\-archives-edgar-data-1291733-000129281419000704-gol20190311_424b5.htm
# forms\-archives-edgar-data-1383094-000119312519073379-d701632d424b5.htm
# forms\-archives-edgar-data-1428439-000119312519071340-d705063d424b5.htm
# forms\-archives-edgar-data-1433642-000143364219000011-hlnes-3asrprosuppmarch2019.htm
# forms\-archives-edgar-data-1433642-000143364219000013-hlnes-3asrfinalprosuppmarc.htm
# forms\-archives-edgar-data-1451512-000147793219000957-trtc_424b5.htm
# forms\-archives-edgar-data-1464423-000119312519074127-d721021d424b5.htm
# forms\-archives-edgar-data-1526125-000104746919001202-a2237980z424b5.htm
# forms\-archives-edgar-data-1526125-000104746919001322-a2238077z424b5.htm
# forms\-archives-edgar-data-1531152-000119312519070970-d597539d424b5.htm
# forms\-archives-edgar-data-1532390-000106299319001223-form424b5.htm
# forms\-archives-edgar-data-1533615-000114420419013712-tv516013_424b5.htm
# forms\-archives-edgar-data-1533615-000114420419014011-tv516183_424b5.htm
# forms\-archives-edgar-data-1539029-000156459019007893-clsd-424b5.htm
# forms\-archives-edgar-data-1545772-000104746919001325-a2238089z424b5.htm
# forms\-archives-edgar-data-1545772-000110465919014756-a19-6503_1424b5.htm
# forms\-archives-edgar-data-1582554-000149315219003340-form424b5.htm
# forms\-archives-edgar-data-1601712-000119312519074118-d723161d424b5.htm
# forms\-archives-edgar-data-1601712-000119312519076890-d723161d424b5.htm
# forms\-archives-edgar-data-1629019-000104746919001320-a2237999z424b5.htm
# forms\-archives-edgar-data-1630472-000119312519074848-d721132d424b5.htm
# forms\-archives-edgar-data-1631825-000119312519072590-d717714d424b5.htm
# forms\-archives-edgar-data-1636050-000104746919001193-a2238033z424b5.htm
# forms\-archives-edgar-data-1636050-000104746919001268-a2238082z424b5.htm
# forms\-archives-edgar-data-1660734-000119312519071486-d717243d424b5.htm
# forms\-archives-edgar-data-1660734-000119312519074470-d717243d424b5.htm
# forms\-archives-edgar-data-1679063-000114420419013152-tv515930_424b5.htm
# forms\-archives-edgar-data-1691221-000121390019004137-f424b5031419_foresightauto.htm
# forms\-archives-edgar-data-1711279-000119312519071463-d712697d424b5.htm
# forms\-archives-edgar-data-1724786-000114420419013334-tv515903_424b5.htm
# forms\-archives-edgar-data-319201-000119312519072813-d706100d424b5.htm
# forms\-archives-edgar-data-319201-000119312519074988-d706100d424b5.htm
# forms\-archives-edgar-data-320017-000032001719000022-prosuppmarch2019equityline.htm
# forms\-archives-edgar-data-40704-000119312519072837-d632461d424b5.htm
# forms\-archives-edgar-data-40704-000119312519074728-d632461d424b5.htm
# forms\-archives-edgar-data-4904-000119312519073713-d703087d424b5.htm
# forms\-archives-edgar-data-70858-000119312519074593-d718897d424b5.htm
# forms\-archives-edgar-data-715957-000119312519070155-d717072d424b5.htm
# forms\-archives-edgar-data-771266-000077126619000024-kopn-2019314x424b5.htm
# forms\-archives-edgar-data-771266-000077126619000030-kopn-2019315x424b5final.htm
# forms\-archives-edgar-data-788611-000149315219003202-form424b5.htm
# forms\-archives-edgar-data-788611-000149315219003268-form424b5.htm
# forms\-archives-edgar-data-788611-000149315219003354-form424b5.htm
# forms\-archives-edgar-data-820027-000104746919001114-a2237979z424b5.htm
# forms\-archives-edgar-data-850261-000114420419014095-tv516214_424b5.htm
# forms\-archives-edgar-data-896493-000121465919002129-d38190424b5.htm
# forms\-archives-edgar-data-899749-000089974919000028-preliminaryprosupp.htm
# forms\-archives-edgar-data-907654-000119312519070964-d718455d424b5.htm
# forms\-archives-edgar-data-909281-000119312519070127-d712751d424b5.htm
# forms\-archives-edgar-data-909281-000119312519072588-d712751d424b5.htm
# forms\-archives-edgar-data-910108-000114420419014027-tv516168_424b5.htm
# forms\-archives-edgar-data-92103-000119312519071420-d628742d424b5.htm
# forms\-archives-edgar-data-92103-000119312519073276-d628742d424b5.htm
# forms\-archives-edgar-data-929869-000119312519072982-d706542d424b5.htm

# %%
window(str(cleaned))

# %%
set([ x[0] for x in all_combinations ])
# Out:
# {'(1)',
#  '(2)',
#  '(3)',
#  '1',
#  'ADSs to preferred share ratio',
#  'Additional Amounts',
#  'Bonds Offered',
#  'Book-Entry Form Only',
#  'Borrowed ADSs offered',
#  'Certain Covenants',
#  'Change of Control Offer',
#  'Change of Control\xa0—\xa0Repurchase at the Option of the Holders',
#  'Class\xa0A common stock offered by us',
#  'Class\xa0A common stock outstanding after this offering',
#  'Common Stock Offered By Us',
#  'Common Stock to be Outstanding After this Offering',
#  'Common shares outstanding prior to this offering',
#  'Common shares to be offered from time to time',
#  'Common stock offered by the selling stockholders',
#  'Common stock offered by us',
#  'Common stock offered by us in this\noffering',
#  'Common stock offered by us:',
#  'Common stock outstanding',
#  'Common stock outstanding after this offering1',
#  'Common stock to be outstanding\n        after this\noffering',
#  'Common stock to be outstanding after this offering',
#  'Common stock to be outstanding immediately after this offering',
#  'Common stock to be outstanding immediately after this offering:',
#  'Common stock we are offering',
#  'Concurrent capped call transactions',
#  'Concurrent offering',
#  'Conflicts of Interest',
#  'Conflicts of interest',
#  'Coupon',
#  'Covenants',
#  'Currency of Payment',
#  'Denomination',
#  'Denominations',
#  'Depositary',
#  'Dividend policy',
#  'Dividends',
#  'Events of Default',
#  'First Interest Payment Date',
#  'Further Issuances',
#  'Further Issues',
#  'Further issuances',
#  'Governing Law',
#  'Guarantee',
#  'Guarantees',
#  'Guarantor',
#  'Interest Payment Dates',
#  'Interest Payments',
#  'Interest Rate',
#  'Interest on the Notes',
#  'Interest on the Series 2019A Bonds',
#  'Interest on the Series 2019B Bonds',
#  'Interest payment date',
#  'Issue Price',
#  'Issuer',
#  'Lending fee',
#  'Listing',
#  'Lock-up',
#  'Manner of Offering',
#  'Manner of offering',
#  'Maturity',
#  'Maturity Date',
#  'Maturity date',
#  'NASDAQ Capital Market Symbol',
#  'NYSE American symbol',
#  'NYSE symbol',
#  'Nasdaq Capital Market Listing',
#  'Nasdaq Capital Market symbol',
#  'Nasdaq symbol',
#  'No Prior Market',
#  'No prior market',
#  'Notes Offered',
#  'Optional Redemption',
#  'Optional Redemption of Notes',
#  'Optional Redemption of Notes for Tax Reasons',
#  'Optional redemption',
#  'Over-allotment option:',
#  'Ownership limit',
#  'Paying Agent',
#  'Preferred shares outstanding immediately after this offering',
#  'Public offering price',
#  'Ranking',
#  'Record Dates',
#  'Redemption for Tax Reasons',
#  'Repurchase upon change of control triggering event',
#  'Risk Factors',
#  'Risk Factors:',
#  'Risk factors',
#  'Securities Offered',
#  'Securities offered',
#  'Security',
#  'Shares of Class\xa0A common stock outstanding before this offering',
#  'Shares of Class\xa0B common stock outstanding before this offering',
#  'Shares of total Class\xa0A and Class\xa0B common stock outstanding before this offering',
#  'Special Trust Fund',
#  'Symbol and Listing',
#  'The ADSs',
#  'The Nasdaq Global Market symbol:',
#  'The Nasdaq Global Select Market symbol',
#  'Trading',
#  'Trustee',
#  'Trustee, Transfer Agent and Book Entry Depositary',
#  'Trustee, Transfer Agent, Registrar and Paying Agent',
#  'U.S. Federal Income Tax Considerations',
#  'Underwriters’ option to purchase additional shares',
#  'Use of Proceeds',
#  'Use of proceeds',
#  '•'}

# %%
for entry in all_combinations:
    if 'symbol' in entry[0].lower():
        m1 = re.search(r'“([A-Z\.]{2,})”', entry[1])
        m2 = re.search(r'[A-Z]{2,}', entry[1])
        print(entry[1], '-->', m1.group(1) if m1 else m2.group(0))
# Out:
# HTGM --> HTGM
# “ROKU” --> ROKU
# Our common stock is listed for trading on The Nasdaq Capital Market and the TSX Venture Exchange under the symbol “WTER”. --> WTER
# “TRTX” --> TRTX
# “KRYS” --> KRYS
# “KOPN.” --> KOPN.
# “KOPN.” --> KOPN.
# “DPW.” --> DPW.
# “ABIO” --> ABIO
# LXP --> LXP

# %%
for entry in all_combinations:
    if 'offer' in entry[0].lower():
        print('----------------------------')
        print(entry[1])
        print('----------------------------')
        doc = nlp(entry[1])
        print( 'MONEY:', [X.text for X in doc.ents if X.label_ == 'MONEY'] )
        print( 'CARDINAL:', [X.text for X in doc.ents if X.label_ == 'CARDINAL'] )
        print( 'DATE:', [X.text for X in doc.ents if X.label_ == 'DATE'] )
        print( 'PERCENT:', [X.text for X in doc.ents if X.label_ == 'PERCENT'] )
# Out:
# ----------------------------
# $                 aggregate principal amount of     % Senior Notes due 2024 and
# $                 aggregate principal amount of     % Senior Notes due 2029.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: ['2024', '2029']
# PERCENT: ['\xa0\xa0\xa0\xa0%']
# ----------------------------
# Following a Change of Control and Ratings Decline (each as defined herein), we will be required to offer to purchase all of the notes at a purchase price equal to 101% of the aggregate
# principal amount of the notes repurchased, plus accrued and unpaid interest, if any, up to but not including the date of repurchase. See “Description of Notes—Repurchase of Notes Upon a Change of Control
# Triggering Event.” The 2013 Credit Facility and the 2014 Credit Facility might restrict our ability to make such a payment.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: ['2013', '2014']
# PERCENT: ['101%']
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $40,000,000.
# ----------------------------
# MONEY: ['up to $40,000,000']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# “At the market offering” that may be made from time to time through or to Cowen, as sales agent or principal. See “Plan of Distribution” on page S-9 of this prospectus supplement.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# Up to 14,000,000 borrowed ADSs (representing up to 28,000,000 preferred shares). The borrowed ADSs are being borrowed from the selling securityholder named in this prospectus supplement. We are not issuing any preferred shares represented by the borrowed ADSs. See “Selling Securityholder.”
# The borrowed ADSs offered hereby may be offered for sale in transactions, including block sales, in the over-the-counter market, in negotiated transactions or otherwise.                      of the borrowed ADSs will be initially sold hereunder at US$        per ADS concurrently with the pricing of the exchangeable senior notes, and the remaining borrowed ADSs may subsequently be sold at prevailing market prices at the time of sale or at negotiated prices.
# ----------------------------
# MONEY: ['US$\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ']
# CARDINAL: ['Up to 14,000,000', 'up to 28,000,000']
# DATE: []
# PERCENT: []
# ----------------------------
# 266,954,154 preferred shares (including 28,000,000 preferred shares represented by the ADSs offered hereby) and 2,863,682,710 common shares. The preferred shares underlying the borrowed ADSs that will be lent to the ADS Borrower by the selling securityholder will be issued and outstanding as fully paid shares for purposes of applicable corporate law.
# ----------------------------
# MONEY: []
# CARDINAL: ['266,954,154', '28,000,000', '2,863,682,710']
# DATE: []
# PERCENT: []
# ----------------------------
# Concurrently with this offering of ADSs, GOL Equity Finance is offering, by means of a separate offering memorandum, US$300.0 million aggregate principal amount of exchangeable senior notes, (i) in accordance with Rule 144A under the Securities Act to “qualified institutional buyers” (as defined in Rule 144A under the Securities Act) that are also qualified purchasers (as defined in Section 2(a)(51) of the Investment Company Act) and (ii) to non-U.S. persons outside the United States in offshore transactions in accordance with Regulation S. GLAI and Gol Linhas Aéreas S.A. will unconditionally and irrevocably guarantee, on a senior unsecured basis, all of GOL Equity Finance’s obligations pursuant to the exchangeable senior notes and the indenture governing the notes. GOL Equity Finance also expects to grant a 30-day option to the initial purchasers of the exchangeable senior notes to purchase up to an additional US$45.0 million aggregate principal amount of the exchangeable senior notes.
# The offering of the borrowed ADSs pursuant to this prospectus supplement and the accompanying prospectus is contingent upon the consummation of the offering of the exchangeable senior notes, and the offering of the exchangeable senior notes is contingent upon the consummation of the offering of the borrowed ADSs hereunder.
# See “Description of the Registered ADS Borrow Facility and Concurrent Offering of Exchangeable Senior Notes” for a description of the exchangeable senior note offering.
# ----------------------------
# MONEY: ['US$300.0', 'an additional US$45.0']
# CARDINAL: ['144A']
# DATE: ['144A', '30-day']
# PERCENT: []
# ----------------------------
# Shares of our Class A common stock having an aggregate offering price of up $100,000,000.
# ----------------------------
# MONEY: ['100,000,000']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 77,819,696 shares
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 31,950,155 shares
# ----------------------------
# MONEY: []
# CARDINAL: ['31,950,155']
# DATE: []
# PERCENT: []
# ----------------------------
# 109,769,851 shares
# ----------------------------
# MONEY: []
# CARDINAL: ['109,769,851']
# DATE: []
# PERCENT: []
# ----------------------------
# “At-the-market” offering that may be made from time to time through or to Citigroup Global Markets Inc.,
# as sales agent and/or principal. See “Plan of Distribution” on page S-9.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 4,000,000 shares (or 4,600,000 shares if the underwriters exercise in full their option to purchase additional shares).
# ----------------------------
# MONEY: []
# CARDINAL: ['4,000,000', '4,600,000']
# DATE: []
# PERCENT: []
# ----------------------------
# 38,670,179 shares (or 39,270,179, if the underwriters exercise their option in full to purchase additional shares).
# ----------------------------
# MONEY: []
# CARDINAL: ['38,670,179', '39,270,179']
# DATE: []
# PERCENT: []
# ----------------------------
# $             aggregate principal amount of     % Senior Notes due 20    .
# ----------------------------
# MONEY: []
# CARDINAL: ['20']
# DATE: []
# PERCENT: ['\xa0\xa0\xa0\xa0%']
# ----------------------------
# $600,000,000 aggregate principal amount of 4.375% Senior Notes due 2024.
# ----------------------------
# MONEY: ['600,000,000']
# CARDINAL: []
# DATE: ['2024']
# PERCENT: ['4.375%']
# ----------------------------
# 6,000,000 shares (plus up to an additional 900,000 shares that we may issue and sell upon the exercise of the underwriters’ option to purchase additional shares of our common stock).
# ----------------------------
# MONEY: []
# CARDINAL: ['6,000,000', 'an additional 900,000']
# DATE: []
# PERCENT: []
# ----------------------------
# 72,018,063 shares (or 72,918,063 shares if the underwriters exercise their option to purchase additional shares of our common stock in full).
# ----------------------------
# MONEY: []
# CARDINAL: ['72,018,063', '72,918,063']
# DATE: []
# PERCENT: []
# ----------------------------
# 1,143,313 shares. The preferences, rights, voting powers, restrictions, limitations as to dividends and other distributions, qualifications and terms and conditions of redemption of the Class A common stock are identical to the common
# stock, except (1) the Class A common stock is not a “margin security” as defined in Regulation U of the Board of Governors of the U.S. Federal Reserve System (and rulings and interpretations thereunder) and may not be listed on a
# national securities exchange or a national market system and (2) each share of Class A common stock is convertible at any time or from time to time, at the option of the holder, for one fully paid and nonassessable share of common stock.
# The Class A common stock votes together with the common stock as a single class.
# ----------------------------
# MONEY: []
# CARDINAL: ['1,143,313', '1', '\xa0', '2', 'one']
# DATE: []
# PERCENT: []
# ----------------------------
# 5,000,000 shares.
# ----------------------------
# MONEY: []
# CARDINAL: ['5,000,000']
# DATE: []
# PERCENT: []
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $50,000,000.
# ----------------------------
# MONEY: ['up to $50,000,000']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# Assuming all $50,000,000 of shares of our common stock are sold in this offering at an assumed offering price of $20.71 per share, the last reported sale price of shares of our common stock on the Nasdaq on March 11, 2019, we would have
# had 16,843,208 shares of our common stock outstanding as of December 31, 2018.
# ----------------------------
# MONEY: ['50,000,000', '20.71']
# CARDINAL: ['16,843,208']
# DATE: ['March\xa011, 2019', 'December\xa031, 2018']
# PERCENT: []
# ----------------------------
# “At-the-market” offering that may be made from time to time through our sales agent, Cowen and Company, LLC. See “Plan of Distribution” on page S-12 of this prospectus supplement.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# $             aggregate principal amount of 20     notes and
# $             aggregate principal amount of 20     notes.
# ----------------------------
# MONEY: []
# CARDINAL: ['20', '20']
# DATE: []
# PERCENT: []
# ----------------------------
# $800,000,000 aggregate principal amount of 2029 notes and $400,000,000 aggregate principal amount of 2049 notes.
# ----------------------------
# MONEY: ['800,000,000', '400,000,000']
# CARDINAL: ['2049']
# DATE: ['2029']
# PERCENT: []
# ----------------------------
# €300,000,000 aggregate principal amount of                % notes due 2020.
# ----------------------------
# MONEY: ['300,000,000']
# CARDINAL: []
# DATE: ['2020']
# PERCENT: []
# ----------------------------
# €300,000,000 aggregate principal amount of 0.000% notes due 2020.
# ----------------------------
# MONEY: ['300,000,000']
# CARDINAL: []
# DATE: ['2020']
# PERCENT: ['0.000%']
# ----------------------------
# shares.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# $ per share
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# shares.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 7,272,727 shares.
# ----------------------------
# MONEY: []
# CARDINAL: ['7,272,727']
# DATE: []
# PERCENT: []
# ----------------------------
# $1.10 per share.
# ----------------------------
# MONEY: ['1.10']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 83,494,791 shares.
# ----------------------------
# MONEY: []
# CARDINAL: ['83,494,791']
# DATE: []
# PERCENT: []
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $100.0 million.
# ----------------------------
# MONEY: ['up to $100.0 million']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# “At the market offering” that may be made from time to time through our sales agent, B. Riley FBR, Inc.  See “Plan of Distribution” on page S-7 of this prospectus supplement.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 180,785 shares of our common stock.
# ----------------------------
# MONEY: []
# CARDINAL: ['180,785']
# DATE: []
# PERCENT: []
# ----------------------------
# 6,482,073 shares of common stock
# ----------------------------
# MONEY: []
# CARDINAL: ['6,482,073']
# DATE: []
# PERCENT: []
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $580,676.
# ----------------------------
# MONEY: ['up to $580,676']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 19,705,834 shares, based on an assumed offering price of $0.4299 per share, the last reported sale price of our common stock on the Exchange on March 8, 2019.
# ----------------------------
# MONEY: ['0.4299']
# CARDINAL: ['19,705,834']
# DATE: ['March\xa08', '\xa02019']
# PERCENT: []
# ----------------------------
# “At the market offering” that may be made from time to time through or to our sales agent, JonesTrading, as sales agent or principal. See “Plan of Distribution” on page S-14 of
# this prospectus supplement.
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# $                 million aggregate principal amount of         % notes due 2029. $                 million aggregate principal amount of 5.20% notes due 2048. The new 2048 notes offered hereby will be an additional issuance of the existing 2048 notes issued by us in an aggregate principal amount of $450 million on July 2, 2018, will be fungible with the existing
# 2048 notes, and will be consolidated with and form a single series with the existing 2048 notes. The new 2048 notes offered hereby will have the same terms as the existing 2048 notes, other than the settlement date and offering price, and will have
# the same CUSIP number as the existing 2048 notes. Immediately after giving effect to the issuance of the new 2048 notes offered hereby, the aggregate principal amount of the new 2048 notes offered hereby and the existing 2048 notes will be
# $                 million.
# ----------------------------
# MONEY: ['$\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 million', '$\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 million', '450', '$\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0million']
# CARDINAL: ['\xa0million']
# DATE: ['2029', '2048', '2048', '2048', 'July\xa02, 2018', '2048', '2048', '2048', '2048', '2048', '2048', '2048', '2048']
# PERCENT: ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0%', '5.20%']
# ----------------------------
# $700 million aggregate principal amount of 4.35% notes due 2029. $550 million aggregate principal amount of 5.20% notes due 2048. The new 2048 notes offered hereby will be an additional issuance of the existing 2048 notes issued by us in an aggregate principal amount of $450 million on July 2, 2018, will be fungible with the existing
# 2048 notes, and will be consolidated with and form a single series with the existing 2048 notes. The new 2048 notes offered hereby will have the same terms as the existing 2048 notes, other than the settlement date and offering price, and will have
# the same CUSIP number as the existing 2048 notes. Immediately after giving effect to the issuance of the new 2048 notes offered hereby, the aggregate principal amount of the new 2048 notes offered hereby and the existing 2048 notes will be $1.0
# billion.
# ----------------------------
# MONEY: ['$700 million', '$550 million', '450', '$1.0\nbillion']
# CARDINAL: ['\xa0million']
# DATE: ['2029', '2048', '2048', '2048', 'July\xa02, 2018', '2048', '2048', '2048', '2048', '2048', '2048', '2048', '2048']
# PERCENT: ['4.35%', '5.20%']
# ----------------------------
# Shares of beneficial interest classified as common stock, par value $0.0001 per share, with an aggregate offering price of up to $100,000,000.00.
# ----------------------------
# MONEY: ['0.0001', 'up to $100,000,000.00']
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# 235,282,784 common shares.(1)
# ----------------------------
# MONEY: []
# CARDINAL: ['235,282,784']
# DATE: []
# PERCENT: []
# ----------------------------
# “At-the-market” offering that may be made from time to time through Jefferies LLC and KeyBanc Capital Markets Inc. as sales agents using commercially reasonable efforts. See “Plan of Distribution.”
# ----------------------------
# MONEY: []
# CARDINAL: []
# DATE: []
# PERCENT: []
# ----------------------------
# $                % First and Refunding Mortgage Bonds, Series 2019A, Due 20     . $                % First and Refunding Mortgage Bonds, Series 2019B, Due 20     .
# ----------------------------
# MONEY: []
# CARDINAL: ['20', '20']
# DATE: ['2019A', '2019B']
# PERCENT: []
# ----------------------------
# $500,000,000 4.20% First and Refunding Mortgage Bonds, Series 2019A, Due 2029. $600,000,000 4.875% First and Refunding Mortgage Bonds, Series 2019B, Due 2049.
# ----------------------------
# MONEY: ['500,000,000', '600,000,000']
# CARDINAL: []
# DATE: ['2019A', '\xa02029', '2019B', '\xa02049']
# PERCENT: ['4.20%', '4.875%']
# ----------------------------
# $950,000,000 aggregate principal amount of 4.000% Notes due 2029
# ----------------------------
# MONEY: ['950,000,000']
# CARDINAL: []
# DATE: ['2029']
# PERCENT: ['4.000%']

# %%
def print_matches(typ, rgx, txt, gnum=0, bl=[]):
    matches = re.finditer(rgx, txt)
    if not matches: return
    for match in matches:
        match_text = match.group(gnum)
        if all([x not in match_text for x in bl]):
            print('-', typ, ':', match.group(gnum))

for entry in all_combinations:
    if not 'offer' in entry[0].lower(): continue
    print('----------------------------')
    print(entry[1])
    
    print_matches('money', r'\$([0-9,\.]+)\s*million', entry[1])
    print_matches('money', r'\$([0-9,\.]+\s*m*)', entry[1], 1, bl=['m'])
    print_matches('percent', r'([0-9\.,]+)\s*%', entry[1], 1)
    print_matches('cardinal', r'\$*\s*([0-9.,][0-9.,]+)\s*%*', entry[1], bl=['%', 'due', '$', '.'])
    print_matches('date', r'due\s*([0-9]+)', entry[1], 1)
# Out:
# ----------------------------
# $                 aggregate principal amount of     % Senior Notes due 2024 and
# $                 aggregate principal amount of     % Senior Notes due 2029.
# - cardinal :  2024
# - date : 2024
# - date : 2029
# ----------------------------
# Following a Change of Control and Ratings Decline (each as defined herein), we will be required to offer to purchase all of the notes at a purchase price equal to 101% of the aggregate
# principal amount of the notes repurchased, plus accrued and unpaid interest, if any, up to but not including the date of repurchase. See “Description of Notes—Repurchase of Notes Upon a Change of Control
# Triggering Event.” The 2013 Credit Facility and the 2014 Credit Facility might restrict our ability to make such a payment.
# - percent : 101
# - cardinal :  2013
# - cardinal :  2014
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $40,000,000.
# - money : 40,000,000.
# ----------------------------
# “At the market offering” that may be made from time to time through or to Cowen, as sales agent or principal. See “Plan of Distribution” on page S-9 of this prospectus supplement.
# ----------------------------
# Up to 14,000,000 borrowed ADSs (representing up to 28,000,000 preferred shares). The borrowed ADSs are being borrowed from the selling securityholder named in this prospectus supplement. We are not issuing any preferred shares represented by the borrowed ADSs. See “Selling Securityholder.”
# The borrowed ADSs offered hereby may be offered for sale in transactions, including block sales, in the over-the-counter market, in negotiated transactions or otherwise.                      of the borrowed ADSs will be initially sold hereunder at US$        per ADS concurrently with the pricing of the exchangeable senior notes, and the remaining borrowed ADSs may subsequently be sold at prevailing market prices at the time of sale or at negotiated prices.
# - cardinal :  14,000,000
# - cardinal :  28,000,000
# ----------------------------
# 266,954,154 preferred shares (including 28,000,000 preferred shares represented by the ADSs offered hereby) and 2,863,682,710 common shares. The preferred shares underlying the borrowed ADSs that will be lent to the ADS Borrower by the selling securityholder will be issued and outstanding as fully paid shares for purposes of applicable corporate law.
# - cardinal : 266,954,154
# - cardinal :  28,000,000
# - cardinal :  2,863,682,710
# ----------------------------
# Concurrently with this offering of ADSs, GOL Equity Finance is offering, by means of a separate offering memorandum, US$300.0 million aggregate principal amount of exchangeable senior notes, (i) in accordance with Rule 144A under the Securities Act to “qualified institutional buyers” (as defined in Rule 144A under the Securities Act) that are also qualified purchasers (as defined in Section 2(a)(51) of the Investment Company Act) and (ii) to non-U.S. persons outside the United States in offshore transactions in accordance with Regulation S. GLAI and Gol Linhas Aéreas S.A. will unconditionally and irrevocably guarantee, on a senior unsecured basis, all of GOL Equity Finance’s obligations pursuant to the exchangeable senior notes and the indenture governing the notes. GOL Equity Finance also expects to grant a 30-day option to the initial purchasers of the exchangeable senior notes to purchase up to an additional US$45.0 million aggregate principal amount of the exchangeable senior notes.
# The offering of the borrowed ADSs pursuant to this prospectus supplement and the accompanying prospectus is contingent upon the consummation of the offering of the exchangeable senior notes, and the offering of the exchangeable senior notes is contingent upon the consummation of the offering of the borrowed ADSs hereunder.
# See “Description of the Registered ADS Borrow Facility and Concurrent Offering of Exchangeable Senior Notes” for a description of the exchangeable senior note offering.
# - money : $300.0 million
# - money : $45.0 million
# - cardinal :  144
# - cardinal :  144
# - cardinal : 51
# - cardinal :  30
# ----------------------------
# Shares of our Class A common stock having an aggregate offering price of up $100,000,000.
# - money : 100,000,000.
# ----------------------------
# 77,819,696 shares
# - cardinal : 77,819,696
# ----------------------------
# 31,950,155 shares
# - cardinal : 31,950,155
# ----------------------------
# 109,769,851 shares
# - cardinal : 109,769,851
# ----------------------------
# “At-the-market” offering that may be made from time to time through or to Citigroup Global Markets Inc.,
# as sales agent and/or principal. See “Plan of Distribution” on page S-9.
# ----------------------------
# 4,000,000 shares (or 4,600,000 shares if the underwriters exercise in full their option to purchase additional shares).
# - cardinal : 4,000,000
# - cardinal :  4,600,000
# ----------------------------
# 38,670,179 shares (or 39,270,179, if the underwriters exercise their option in full to purchase additional shares).
# - cardinal : 38,670,179
# - cardinal :  39,270,179,
# ----------------------------
# $             aggregate principal amount of     % Senior Notes due 20    .
# - cardinal :  20
# - date : 20
# ----------------------------
# $600,000,000 aggregate principal amount of 4.375% Senior Notes due 2024.
# - money : 600,000,000
# - percent : 4.375
# - date : 2024
# ----------------------------
# 6,000,000 shares (plus up to an additional 900,000 shares that we may issue and sell upon the exercise of the underwriters’ option to purchase additional shares of our common stock).
# - cardinal : 6,000,000
# - cardinal :  900,000
# ----------------------------
# 72,018,063 shares (or 72,918,063 shares if the underwriters exercise their option to purchase additional shares of our common stock in full).
# - cardinal : 72,018,063
# - cardinal :  72,918,063
# ----------------------------
# 1,143,313 shares. The preferences, rights, voting powers, restrictions, limitations as to dividends and other distributions, qualifications and terms and conditions of redemption of the Class A common stock are identical to the common
# stock, except (1) the Class A common stock is not a “margin security” as defined in Regulation U of the Board of Governors of the U.S. Federal Reserve System (and rulings and interpretations thereunder) and may not be listed on a
# national securities exchange or a national market system and (2) each share of Class A common stock is convertible at any time or from time to time, at the option of the holder, for one fully paid and nonassessable share of common stock.
# The Class A common stock votes together with the common stock as a single class.
# - cardinal : 1,143,313
# ----------------------------
# 5,000,000 shares.
# - cardinal : 5,000,000
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $50,000,000.
# - money : 50,000,000.
# ----------------------------
# Assuming all $50,000,000 of shares of our common stock are sold in this offering at an assumed offering price of $20.71 per share, the last reported sale price of shares of our common stock on the Nasdaq on March 11, 2019, we would have
# had 16,843,208 shares of our common stock outstanding as of December 31, 2018.
# - money : 50,000,000
# - money : 20.71
# - cardinal :  11,
# - cardinal : 2019,
# - cardinal :  16,843,208
# - cardinal :  31,
# ----------------------------
# “At-the-market” offering that may be made from time to time through our sales agent, Cowen and Company, LLC. See “Plan of Distribution” on page S-12 of this prospectus supplement.
# - cardinal : 12
# ----------------------------
# $             aggregate principal amount of 20     notes and
# $             aggregate principal amount of 20     notes.
# - cardinal :  20
# - cardinal :  20
# ----------------------------
# $800,000,000 aggregate principal amount of 2029 notes and $400,000,000 aggregate principal amount of 2049 notes.
# - money : 800,000,000
# - money : 400,000,000
# - cardinal :  2029
# - cardinal :  2049
# ----------------------------
# €300,000,000 aggregate principal amount of                % notes due 2020.
# - cardinal : 300,000,000
# - date : 2020
# ----------------------------
# €300,000,000 aggregate principal amount of 0.000% notes due 2020.
# - percent : 0.000
# - cardinal : 300,000,000
# - date : 2020
# ----------------------------
# shares.
# ----------------------------
# $ per share
# ----------------------------
# shares.
# ----------------------------
# 7,272,727 shares.
# - cardinal : 7,272,727
# ----------------------------
# $1.10 per share.
# - money : 1.10
# ----------------------------
# 83,494,791 shares.
# - cardinal : 83,494,791
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $100.0 million.
# - money : $100.0 million
# ----------------------------
# “At the market offering” that may be made from time to time through our sales agent, B. Riley FBR, Inc.  See “Plan of Distribution” on page S-7 of this prospectus supplement.
# ----------------------------
# 180,785 shares of our common stock.
# - cardinal : 180,785
# ----------------------------
# 6,482,073 shares of common stock
# - cardinal : 6,482,073
# ----------------------------
# Shares of our common stock having an aggregate offering price of up to $580,676.
# - money : 580,676.
# ----------------------------
# 19,705,834 shares, based on an assumed offering price of $0.4299 per share, the last reported sale price of our common stock on the Exchange on March 8, 2019.
# - money : 0.4299
# - cardinal : 19,705,834
# - cardinal :  8,
# ----------------------------
# “At the market offering” that may be made from time to time through or to our sales agent, JonesTrading, as sales agent or principal. See “Plan of Distribution” on page S-14 of
# this prospectus supplement.
# - cardinal : 14
# ----------------------------
# $                 million aggregate principal amount of         % notes due 2029. $                 million aggregate principal amount of 5.20% notes due 2048. The new 2048 notes offered hereby will be an additional issuance of the existing 2048 notes issued by us in an aggregate principal amount of $450 million on July 2, 2018, will be fungible with the existing
# 2048 notes, and will be consolidated with and form a single series with the existing 2048 notes. The new 2048 notes offered hereby will have the same terms as the existing 2048 notes, other than the settlement date and offering price, and will have
# the same CUSIP number as the existing 2048 notes. Immediately after giving effect to the issuance of the new 2048 notes offered hereby, the aggregate principal amount of the new 2048 notes offered hereby and the existing 2048 notes will be
# $                 million.
# - money : $450 million
# - percent : 5.20
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2,
# - cardinal : 2018,
# - cardinal :
# 2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - date : 2029
# - date : 2048
# ----------------------------
# $700 million aggregate principal amount of 4.35% notes due 2029. $550 million aggregate principal amount of 5.20% notes due 2048. The new 2048 notes offered hereby will be an additional issuance of the existing 2048 notes issued by us in an aggregate principal amount of $450 million on July 2, 2018, will be fungible with the existing
# 2048 notes, and will be consolidated with and form a single series with the existing 2048 notes. The new 2048 notes offered hereby will have the same terms as the existing 2048 notes, other than the settlement date and offering price, and will have
# the same CUSIP number as the existing 2048 notes. Immediately after giving effect to the issuance of the new 2048 notes offered hereby, the aggregate principal amount of the new 2048 notes offered hereby and the existing 2048 notes will be $1.0
# billion.
# - money : $700 million
# - money : $550 million
# - money : $450 million
# - money : 1.0
#
# - percent : 4.35
# - percent : 5.20
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2,
# - cardinal : 2018,
# - cardinal :
# 2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - cardinal :  2048
# - date : 2029
# - date : 2048
# ----------------------------
# Shares of beneficial interest classified as common stock, par value $0.0001 per share, with an aggregate offering price of up to $100,000,000.00.
# - money : 0.0001
# - money : 100,000,000.00.
# ----------------------------
# 235,282,784 common shares.(1)
# - cardinal : 235,282,784
# ----------------------------
# “At-the-market” offering that may be made from time to time through Jefferies LLC and KeyBanc Capital Markets Inc. as sales agents using commercially reasonable efforts. See “Plan of Distribution.”
# ----------------------------
# $                % First and Refunding Mortgage Bonds, Series 2019A, Due 20     . $                % First and Refunding Mortgage Bonds, Series 2019B, Due 20     .
# - cardinal :  2019
# - cardinal :  20
# - cardinal :  2019
# - cardinal :  20
# ----------------------------
# $500,000,000 4.20% First and Refunding Mortgage Bonds, Series 2019A, Due 2029. $600,000,000 4.875% First and Refunding Mortgage Bonds, Series 2019B, Due 2049.
# - money : 500,000,000
# - money : 600,000,000
# - percent : 4.20
# - percent : 4.875
# - cardinal :  2019
# - cardinal :  2019
# ----------------------------
# $950,000,000 aggregate principal amount of 4.000% Notes due 2029
# - money : 950,000,000
# - percent : 4.000
# - cardinal :  2029
# - date : 2029
